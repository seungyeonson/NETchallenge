# %%
import tensorflow as tf
#Data Manipulation
import numpy as np
import pandas as pd

#Visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

#Importing Dependencies
# %matplotlib inline

import math
# Out:
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-beae429d9868> in <module>
# ----> 1 import tensorflow as tf
#       2 #Data Manipulation
#       3 import numpy as np
#       4 import pandas as pd
#       5
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\__init__.py in <module>
#      26
#      27 # pylint: disable=g-bad-import-order
# ---> 28 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      29 from tensorflow.python.tools import module_util as _module_util
#      30
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\__init__.py in <module>
#      81 from tensorflow.python import data
#      82 from tensorflow.python import distribute
# ---> 83 from tensorflow.python import keras
#      84 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      85 from tensorflow.python.layers import layers
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\__init__.py in <module>
#      24 from tensorflow.python import tf2
#      25
# ---> 26 from tensorflow.python.keras import activations
#      27 from tensorflow.python.keras import applications
#      28 from tensorflow.python.keras import backend
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\activations.py in <module>
#      22
#      23 from tensorflow.python.keras import backend as K
# ---> 24 from tensorflow.python.keras.utils.generic_utils import deserialize_keras_object
#      25 from tensorflow.python.ops import math_ops
#      26 from tensorflow.python.ops import nn
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\utils\__init__.py in <module>
#      37 from tensorflow.python.keras.utils.layer_utils import print_summary
#      38 from tensorflow.python.keras.utils.losses_utils import squeeze_or_expand_dimensions
# ---> 39 from tensorflow.python.keras.utils.multi_gpu_utils import multi_gpu_model
#      40 from tensorflow.python.keras.utils.np_utils import normalize
#      41 from tensorflow.python.keras.utils.np_utils import to_categorical
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\utils\multi_gpu_utils.py in <module>
#      20 from tensorflow.python.framework import ops
#      21 from tensorflow.python.keras import backend as K
# ---> 22 from tensorflow.python.keras.engine.training import Model
#      23 from tensorflow.python.ops import array_ops
#      24 from tensorflow.python.util.tf_export import keras_export
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\engine\__init__.py in <module>
#      21 # TODO(fchollet): Remove hourglass imports once external code is done importing
#      22 # non-public APIs.
# ---> 23 from tensorflow.python.keras.engine.base_layer import Layer
#      24 from tensorflow.python.keras.engine.input_layer import Input
#      25 from tensorflow.python.keras.engine.input_layer import InputLayer
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in <module>
#      45 from tensorflow.python.keras.engine import base_layer_utils
#      46 from tensorflow.python.keras.engine import input_spec
# ---> 47 from tensorflow.python.keras.mixed_precision.experimental import autocast_variable
#      48 from tensorflow.python.keras.mixed_precision.experimental import policy
#      49 from tensorflow.python.keras.utils import generic_utils
#
# ~\Anaconda3\envs\tensorflow\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\Anaconda3\envs\tensorflow\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\Anaconda3\envs\tensorflow\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\Anaconda3\envs\tensorflow\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\Anaconda3\envs\tensorflow\lib\importlib\_bootstrap_external.py in get_code(self, fullname)
#
# ~\Anaconda3\envs\tensorflow\lib\importlib\_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %%
#파일 불러오기
ap_data = pd.read_csv('LOG_CONCAT_ssy.csv', engine='python', index_col=0)

# %%
ap_data.head(5)

# %%
ap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 125115 entries, 3.0 to 72799.0
# Data columns (total 31 columns):
# jnuradacctid            125024 non-null float64
# acctsessionid           125020 non-null object
# acctuniqueid            125024 non-null object
# username                125024 non-null object
# groupname               0 non-null float64
# realm                   3664 non-null object
# nasipaddress            125024 non-null object
# nasportid               125024 non-null float64
# nasporttype             125024 non-null object
# acctstarttime           125024 non-null object
# acctstoptime            125024 non-null object
# real_time               125024 non-null object
# acctsessiontime         125115 non-null int64
# acctauthentic           118367 non-null object
# connectinfo_start       51343 non-null object
# connectinfo_stop        42621 non-null object
# acctinputoctets         125024 non-null float64
# acctoutputoctets        125024 non-null float64
# calledstationid         125024 non-null object
# ipaddress               125024 non-null object
# place                   124068 non-null object
# callingstationid        125024 non-null object
# acctterminatecause      107381 non-null object
# servicetype             0 non-null float64
# framedprotocol          0 non-null float64
# framedipaddress         125024 non-null object
# acctstartdelay          125024 non-null float64
# acctstopdelay           125024 non-null float64
# xascendsessionsvrkey    0 non-null float64
# server                  125024 non-null object
# number                  125115 non-null int64
# dtypes: float64(10), int64(2), object(19)
# memory usage: 30.5+ MB

# %%
ap_data = ap_data.reset_index(drop=True)

# %%
ap_data.head(5)
# Out:
#    jnuradacctid      acctsessionid                      acctuniqueid username  \
# 0    80667513.0  00002801-00000470  977346d2dd8a9ba2d2eb0a07c9c81541   192777
# 1    80667663.0  00003001-0000023D  45c4ba1bc250e54cfe82030e9c09ad1a   171594
# 2    80668351.0  00004001-00000236  d115f6d0b261fc722c5ec9a04823f9f3   193562
# 3    80675437.0  00021401-000011DC  7bb6ebbfe7ef1f768ace5bbf47c061f1   193562
# 4    80675438.0  00021401-000011DD  6b69327f47c917102170c73c08032506   142825
#
#    groupname realm    nasipaddress  nasportid      nasporttype  \
# 0        NaN   NaN  168.131.13.224        0.0  Wireless-802.11
# 1        NaN   NaN  168.131.13.224        0.0  Wireless-802.11
# 2        NaN   NaN  168.131.13.224        0.0  Wireless-802.11
# 3        NaN   NaN  168.131.13.222        0.0  Wireless-802.11
# 4        NaN   NaN  168.131.13.222        0.0  Wireless-802.11
#
#      acctstarttime  ...   callingstationid acctterminatecause  servicetype  \
# 0  2019-09-20 0:25  ...  08-AE-D6-30-A0-33                NaN          NaN
# 1  2019-09-20 1:24  ...  A8-2B-B9-19-C8-5C       User-Request          NaN
# 2  2019-09-20 0:22  ...  C4-93-D9-CE-A7-5D       User-Request          NaN
# 3  2019-09-20 0:26  ...  C4-93-D9-CE-A7-5D       User-Request          NaN
# 4  2019-09-20 0:55  ...  64-7B-CE-8D-64-7A                NaN          NaN
#
#   framedprotocol framedipaddress acctstartdelay  acctstopdelay  \
# 0            NaN     10.10.12.83            0.0            0.0
# 1            NaN     10.10.1.144            0.0            0.0
# 2            NaN  168.131.214.29            0.0            0.0
# 3            NaN    10.10.40.252            0.0            0.0
# 4            NaN    10.10.60.142            0.0            0.0
#
#    xascendsessionsvrkey         server number
# 0                   NaN  168.131.33.63      0
# 1                   NaN  168.131.33.63      1
# 2                   NaN  168.131.33.63      2
# 3                   NaN  168.131.33.63      3
# 4                   NaN  168.131.33.63      4
#
# [5 rows x 31 columns]

# %%
#사용할 칼럼만 추출
ap_data = ap_data[["username","number","place","acctstarttime","acctstoptime",'real_time',"acctsessiontime","calledstationid","ipaddress","callingstationid"]]

# %%
ap_data.head(10)
# Out:
#   username  number     place    acctstarttime     acctstoptime real_time  \
# 0   192777       0       NaN  2019-09-20 0:25  2019-09-20 0:38   0:12:23
# 1   171594       1     정보전산원  2019-09-20 1:24  2019-09-20 1:40   0:15:25
# 2   193562       2     정보전산원  2019-09-20 0:22  2019-09-20 0:39   0:16:16
# 3   193562       3  공과대학 5호관  2019-09-20 0:26  2019-09-20 0:48   0:22:28
# 4   142825       4  공과대학 5호관  2019-09-20 0:55  2019-09-20 1:15   0:19:10
# 5   174905       5  공과대학 5호관  2019-09-20 0:38  2019-09-20 0:56   0:18:31
# 6   157302       6  공과대학 5호관  2019-09-20 0:49  2019-09-20 1:04   0:15:00
# 7   178659       7  공과대학 7호관  2019-09-20 1:15  2019-09-20 1:35   0:19:43
# 8   182638       8  공과대학 2호관  2019-09-20 0:29  2019-09-20 0:50   0:20:45
# 9   164253       9  공과대학 1호관  2019-09-20 1:00  2019-09-20 1:24   0:24:08
#
#    acctsessiontime calledstationid        ipaddress   callingstationid
# 0              743    F4D9FBE30A20  168.131.184.176  08-AE-D6-30-A0-33
# 1              925    F4D9FBE30AE0  168.131.184.178  A8-2B-B9-19-C8-5C
# 2              976    F4D9FBEA1FE0  168.131.184.183  C4-93-D9-CE-A7-5D
# 3             1348    20DBAB6CB340  168.131.180.138  C4-93-D9-CE-A7-5D
# 4             1150    20DBAB6CB340  168.131.180.138  64-7B-CE-8D-64-7A
# 5             1111    F4D9FBDF9000  168.131.180.139  64-C2-DE-73-D5-B5
# 6              900    F4D9FBDF9000  168.131.180.139  50-77-05-07-27-FD
# 7             1183    20DBAB7A2140  168.131.180.208  A8-7C-01-F4-0E-6E
# 8             1245    20DBAB6CAC40   168.131.180.50  50-77-05-6D-82-F1
# 9             1448    F4D9FBDDF900   168.131.180.21  F8-E6-1A-8A-97-37

# %%
ap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125115 entries, 0 to 125114
# Data columns (total 15 columns):
# username                125024 non-null object
# number                  125115 non-null int64
# place                   124068 non-null object
# acctstarttime           125024 non-null datetime64[ns]
# acctstoptime            125024 non-null datetime64[ns]
# real_time               125024 non-null object
# acctsessiontime         125115 non-null int64
# calledstationid         125024 non-null object
# ipaddress               125024 non-null object
# callingstationid        125024 non-null object
# acctstarttime_year      125024 non-null float64
# acctstarttime_month     125024 non-null float64
# acctstarttime_day       125024 non-null float64
# acctstarttime_hour      125024 non-null float64
# acctstarttime_minute    125024 non-null float64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(6)
# memory usage: 14.3+ MB

# %%
ap_data.head(5)
# Out:
#   username  number     place       acctstarttime        acctstoptime  \
# 0   192777       0       NaN 2019-09-20 00:25:00 2019-09-20 00:38:00
# 1   171594       1     정보전산원 2019-09-20 01:24:00 2019-09-20 01:40:00
# 2   193562       2     정보전산원 2019-09-20 00:22:00 2019-09-20 00:39:00
# 3   193562       3  공과대학 5호관 2019-09-20 00:26:00 2019-09-20 00:48:00
# 4   142825       4  공과대학 5호관 2019-09-20 00:55:00 2019-09-20 01:15:00
#
#   real_time  acctsessiontime calledstationid        ipaddress  \
# 0   0:12:23              743    F4D9FBE30A20  168.131.184.176
# 1   0:15:25              925    F4D9FBE30AE0  168.131.184.178
# 2   0:16:16              976    F4D9FBEA1FE0  168.131.184.183
# 3   0:22:28             1348    20DBAB6CB340  168.131.180.138
# 4   0:19:10             1150    20DBAB6CB340  168.131.180.138
#
#     callingstationid  acctstarttime_year  acctstarttime_month  \
# 0  08-AE-D6-30-A0-33              2019.0                  9.0
# 1  A8-2B-B9-19-C8-5C              2019.0                  9.0
# 2  C4-93-D9-CE-A7-5D              2019.0                  9.0
# 3  C4-93-D9-CE-A7-5D              2019.0                  9.0
# 4  64-7B-CE-8D-64-7A              2019.0                  9.0
#
#    acctstarttime_day  acctstarttime_hour  acctstarttime_minute
# 0               20.0                 0.0                  25.0
# 1               20.0                 1.0                  24.0
# 2               20.0                 0.0                  22.0
# 3               20.0                 0.0                  26.0
# 4               20.0                 0.0                  55.0

# %%
ap_data.isnull().sum()
# Out:
# username                  91
# number                     0
# place                   1047
# acctstarttime             91
# acctstoptime              91
# real_time                 91
# acctsessiontime            0
# calledstationid           91
# ipaddress                 91
# callingstationid          91
# acctstarttime_year        91
# acctstarttime_month       91
# acctstarttime_day         91
# acctstarttime_hour        91
# acctstarttime_minute      91
# dtype: int64

# %%
#null값을 가진 행 모두 제거
ap_data = ap_data.dropna(how = 'any',axis = 0)

# %%
ap_data.sort_index(axis = 1)
# Out:
#         acctsessiontime       acctstarttime  acctstarttime_day  \
# 1                   925 2019-09-20 01:24:00               20.0
# 2                   976 2019-09-20 00:22:00               20.0
# 3                  1348 2019-09-20 00:26:00               20.0
# 4                  1150 2019-09-20 00:55:00               20.0
# 5                  1111 2019-09-20 00:38:00               20.0
# ...                 ...                 ...                ...
# 125110              215 2019-09-24 22:22:00               24.0
# 125111              288 2019-09-24 07:36:00               24.0
# 125112               27 2019-09-24 15:49:00               24.0
# 125113              290 2019-09-24 15:50:00               24.0
# 125114               29 2019-09-24 17:25:00               24.0
#
#         acctstarttime_hour  acctstarttime_minute  acctstarttime_month  \
# 1                      1.0                  24.0                  9.0
# 2                      0.0                  22.0                  9.0
# 3                      0.0                  26.0                  9.0
# 4                      0.0                  55.0                  9.0
# 5                      0.0                  38.0                  9.0
# ...                    ...                   ...                  ...
# 125110                22.0                  22.0                  9.0
# 125111                 7.0                  36.0                  9.0
# 125112                15.0                  49.0                  9.0
# 125113                15.0                  50.0                  9.0
# 125114                17.0                  25.0                  9.0
#
#         acctstarttime_year        acctstoptime calledstationid  \
# 1                   2019.0 2019-09-20 01:40:00    F4D9FBE30AE0
# 2                   2019.0 2019-09-20 00:39:00    F4D9FBEA1FE0
# 3                   2019.0 2019-09-20 00:48:00    20DBAB6CB340
# 4                   2019.0 2019-09-20 01:15:00    20DBAB6CB340
# 5                   2019.0 2019-09-20 00:56:00    F4D9FBDF9000
# ...                    ...                 ...             ...
# 125110              2019.0 2019-09-24 22:26:00    34FCB96C1990
# 125111              2019.0 2019-09-24 07:41:00    34FCB96AF2F0
# 125112              2019.0 2019-09-24 15:49:00    34FCB96AF2F0
# 125113              2019.0 2019-09-24 15:55:00    34FCB96AF2F0
# 125114              2019.0 2019-09-24 17:26:00    34FCB96AF2F0
#
#          callingstationid        ipaddress  number      place real_time  \
# 1       A8-2B-B9-19-C8-5C  168.131.184.178       1      정보전산원   0:15:25
# 2       C4-93-D9-CE-A7-5D  168.131.184.183       2      정보전산원   0:16:16
# 3       C4-93-D9-CE-A7-5D  168.131.180.138       3   공과대학 5호관   0:22:28
# 4       64-7B-CE-8D-64-7A  168.131.180.138       4   공과대학 5호관   0:19:10
# 5       64-C2-DE-73-D5-B5  168.131.180.139       5   공과대학 5호관   0:18:31
# ...                   ...              ...     ...        ...       ...
# 125110       BCB8639FA99B  168.131.181.114  125110     도서관열람실   0:03:35
# 125111       C81EE7A46B92  168.131.181.102  125111  도서관별관(백도)   0:04:48
# 125112       C81EE7A46B92  168.131.181.102  125112  도서관별관(백도)   0:00:27
# 125113       C81EE7A46B92  168.131.181.102  125113  도서관별관(백도)   0:04:50
# 125114       C81EE7A46B92  168.131.181.102  125114  도서관별관(백도)   0:00:29
#
#        username
# 1        171594
# 2        193562
# 3        193562
# 4        142825
# 5        174905
# ...         ...
# 125110   112763
# 125111   112771
# 125112   112771
# 125113   112771
# 125114   112771
#
# [124068 rows x 15 columns]

# %%
ap_data.shape
# Out:
# (124068, 15)

# %%
ap_data.head(5)
# Out:
#   username  number     place       acctstarttime        acctstoptime  \
# 1   171594       1     정보전산원 2019-09-20 01:24:00 2019-09-20 01:40:00
# 2   193562       2     정보전산원 2019-09-20 00:22:00 2019-09-20 00:39:00
# 3   193562       3  공과대학 5호관 2019-09-20 00:26:00 2019-09-20 00:48:00
# 4   142825       4  공과대학 5호관 2019-09-20 00:55:00 2019-09-20 01:15:00
# 5   174905       5  공과대학 5호관 2019-09-20 00:38:00 2019-09-20 00:56:00
#
#   real_time  acctsessiontime calledstationid        ipaddress  \
# 1   0:15:25              925    F4D9FBE30AE0  168.131.184.178
# 2   0:16:16              976    F4D9FBEA1FE0  168.131.184.183
# 3   0:22:28             1348    20DBAB6CB340  168.131.180.138
# 4   0:19:10             1150    20DBAB6CB340  168.131.180.138
# 5   0:18:31             1111    F4D9FBDF9000  168.131.180.139
#
#     callingstationid  acctstarttime_year  acctstarttime_month  \
# 1  A8-2B-B9-19-C8-5C              2019.0                  9.0
# 2  C4-93-D9-CE-A7-5D              2019.0                  9.0
# 3  C4-93-D9-CE-A7-5D              2019.0                  9.0
# 4  64-7B-CE-8D-64-7A              2019.0                  9.0
# 5  64-C2-DE-73-D5-B5              2019.0                  9.0
#
#    acctstarttime_day  acctstarttime_hour  acctstarttime_minute
# 1               20.0                 1.0                  24.0
# 2               20.0                 0.0                  22.0
# 3               20.0                 0.0                  26.0
# 4               20.0                 0.0                  55.0
# 5               20.0                 0.0                  38.0

# %%
# ap_data.describe()

# %%
# date_data =pd.DataFrame()
# date_data.loc[:,'date']=pd.Series(pd.date_range("2019-9-20 00:00", "2019-9-25 00:00", freq="H"))
# date_data['all_num']=0

# date_data['datetime'] = pd.to_datetime(date_data['date'])
# date_data = date_data.set_index("datetime")
# date_data.head(20)

# %%
date_data =pd.DataFrame()
date_data.loc[:,'date']=pd.Series(pd.date_range("2019-9-20", "2019-9-25", freq="60T"))

#여기서 00:00:00의 all_num의 의미는 0-5분까지의 사람 숫자로 계산할 것이다.
date_data['all_num']=0
date_data.info()
# date_data.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 2 columns):
# date       121 non-null datetime64[ns]
# all_num    121 non-null int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.0 KB

# %%
date_data.head(5)
# Out:
#                  date  all_num
# 0 2019-09-20 00:00:00        0
# 1 2019-09-20 01:00:00        0
# 2 2019-09-20 02:00:00        0
# 3 2019-09-20 03:00:00        0
# 4 2019-09-20 04:00:00        0

# %%
# date_data.iloc[:,0]

# %%
class Queue:
    queue = []
    
    def __init__(self):
        self.queue = [] 
 
    def push(self, num):
        if self.size() == 10:
            self.pop()
        self.queue.append(num)
        
 
    def pop(self):
        return self.queue.pop(0) if len(self.queue) != 0 else -1
 
    def size(self):
        return len(self.queue)
 
    def empty(self):
        return 1 if self.size() == 0 else 0
 
    def front(self):
        return self.queue[0] if self.size() != 0 else -1
 
    def back(self):
        return self.queue[-1] if self.size() != 0 else -1

# %%
 
#몇개의 숫자를 받을건지

queue = Queue()
queue.push(1)
queue.push(2)
queue.push(3)
queue.push(4)
queue.push(5)
queue.push(6)
queue.push(7)
queue.push(8)
queue.push(9)
queue.push(10)
queue.push(11)
queue.push(12)
queue.pop()
queue.pop()
queue.pop()

# count = list_duplicates_of(queue,7)
# print(count)
print(queue.queue)
# Out:
# [6, 7, 8, 9, 10, 11, 12]

# %%
# 중복 인덱스 값 추출

def list_duplicates_of(seq,item):
    start_at = -1
    locs = []
    while True:
        try:
            loc = seq.index(item,start_at+1)
        except ValueError:
            break
        else:
            locs.append(loc)
            start_at = loc
    return locs

# %%
list = [7]
value =list[0]

# %%
list_duplicates_of(queue.queue,list[0])
# Out:
# [1]

# %%
queue.queue[1]
# Out:
# 7

# %%
ap_data = ap_data.loc[(ap_data['calledstationid']=='34FCB96AF2F0'),:]

# %%
ap_data['username'].value_counts()
# Out:
# 112771      40
# 165265      34
# 150166      33
# 190226      28
# 65716       28
#             ..
# 194248       1
# 140356       1
# 148826       1
# 92646        1
# brendan2     1
# Name: username, Length: 536, dtype: int64

# %%
ap_data = ap_data.sort_values(by = 'acctstarttime', ascending = True)

# %%
ap_data.head(20)
# Out:
#       username  number      place       acctstarttime        acctstoptime  \
# 39457   176272   39457  도서관별관(백도) 2019-09-20 07:32:00 2019-09-20 07:34:00
# 17997   176272   17997  도서관별관(백도) 2019-09-20 07:32:00 2019-09-20 07:34:00
# 33702   120286   33702  도서관별관(백도) 2019-09-20 08:09:00 2019-09-20 08:12:00
# 9994    120286    9994  도서관별관(백도) 2019-09-20 08:09:00 2019-09-20 08:12:00
# 33824   120815   33824  도서관별관(백도) 2019-09-20 08:11:00 2019-09-20 08:12:00
# 10066   120815   10066  도서관별관(백도) 2019-09-20 08:11:00 2019-09-20 08:12:00
# 32678   131528   32678  도서관별관(백도) 2019-09-20 08:11:00 2019-09-20 08:12:00
# 12130   131528   12130  도서관별관(백도) 2019-09-20 08:11:00 2019-09-20 08:12:00
# 10968   150638   10968  도서관별관(백도) 2019-09-20 08:26:00 2019-09-20 08:27:00
# 36106   150638   36106  도서관별관(백도) 2019-09-20 08:26:00 2019-09-20 08:27:00
# 10969   150638   10969  도서관별관(백도) 2019-09-20 08:27:00 2019-09-20 08:29:00
# 36107   150638   36107  도서관별관(백도) 2019-09-20 08:27:00 2019-09-20 08:29:00
# 9288    112771    9288  도서관별관(백도) 2019-09-20 08:30:00 2019-09-20 08:32:00
# 32734   112771   32734  도서관별관(백도) 2019-09-20 08:30:00 2019-09-20 08:32:00
# 33493   133015   33493  도서관별관(백도) 2019-09-20 08:33:00 2019-09-20 08:40:00
# 12678   133015   12678  도서관별관(백도) 2019-09-20 08:33:00 2019-09-20 08:40:00
# 38744   161360   38744  도서관별관(백도) 2019-09-20 08:39:00 2019-09-20 08:44:00
# 34054   133575   34054  도서관별관(백도) 2019-09-20 08:39:00 2019-09-20 08:40:00
# 10906   161360   10906  도서관별관(백도) 2019-09-20 08:39:00 2019-09-20 08:44:00
# 13115   133575   13115  도서관별관(백도) 2019-09-20 08:39:00 2019-09-20 08:40:00
#
#       real_time  acctsessiontime calledstationid        ipaddress  \
# 39457   0:01:36               96    34FCB96AF2F0  168.131.181.102
# 17997   0:01:36               96    34FCB96AF2F0  168.131.181.102
# 33702   0:03:26              206    34FCB96AF2F0  168.131.181.102
# 9994    0:03:26              206    34FCB96AF2F0  168.131.181.102
# 33824   0:00:47               47    34FCB96AF2F0  168.131.181.102
# 10066   0:00:47               47    34FCB96AF2F0  168.131.181.102
# 32678   0:00:47               47    34FCB96AF2F0  168.131.181.102
# 12130   0:00:47               47    34FCB96AF2F0  168.131.181.102
# 10968   0:00:35               35    34FCB96AF2F0  168.131.181.102
# 36106   0:00:35               35    34FCB96AF2F0  168.131.181.102
# 10969   0:02:17              137    34FCB96AF2F0  168.131.181.102
# 36107   0:02:17              137    34FCB96AF2F0  168.131.181.102
# 9288    0:01:31               91    34FCB96AF2F0  168.131.181.102
# 32734   0:01:31               91    34FCB96AF2F0  168.131.181.102
# 33493   0:07:06              426    34FCB96AF2F0  168.131.181.102
# 12678   0:07:06              426    34FCB96AF2F0  168.131.181.102
# 38744   0:05:11              311    34FCB96AF2F0  168.131.181.102
# 34054   0:00:47               47    34FCB96AF2F0  168.131.181.102
# 10906   0:05:11              311    34FCB96AF2F0  168.131.181.102
# 13115   0:00:47               47    34FCB96AF2F0  168.131.181.102
#
#       callingstationid  acctstarttime_year  acctstarttime_month  \
# 39457     9CE6E7CDDA56              2019.0                  9.0
# 17997     9CE6E7CDDA56              2019.0                  9.0
# 33702     D02B20B276E4              2019.0                  9.0
# 9994      D02B20B276E4              2019.0                  9.0
# 33824     FC183C4C9280              2019.0                  9.0
# 10066     FC183C4C9280              2019.0                  9.0
# 32678     749EAF17113F              2019.0                  9.0
# 12130     749EAF17113F              2019.0                  9.0
# 10968     18F643292270              2019.0                  9.0
# 36106     18F643292270              2019.0                  9.0
# 10969     18F643292270              2019.0                  9.0
# 36107     18F643292270              2019.0                  9.0
# 9288      C81EE7A46B92              2019.0                  9.0
# 32734     C81EE7A46B92              2019.0                  9.0
# 33493     F8E94EA2C5D3              2019.0                  9.0
# 12678     F8E94EA2C5D3              2019.0                  9.0
# 38744     08AED644F8DB              2019.0                  9.0
# 34054     D868C36D1DD1              2019.0                  9.0
# 10906     08AED644F8DB              2019.0                  9.0
# 13115     D868C36D1DD1              2019.0                  9.0
#
#        acctstarttime_day  acctstarttime_hour  acctstarttime_minute
# 39457               20.0                 7.0                  32.0
# 17997               20.0                 7.0                  32.0
# 33702               20.0                 8.0                   9.0
# 9994                20.0                 8.0                   9.0
# 33824               20.0                 8.0                  11.0
# 10066               20.0                 8.0                  11.0
# 32678               20.0                 8.0                  11.0
# 12130               20.0                 8.0                  11.0
# 10968               20.0                 8.0                  26.0
# 36106               20.0                 8.0                  26.0
# 10969               20.0                 8.0                  27.0
# 36107               20.0                 8.0                  27.0
# 9288                20.0                 8.0                  30.0
# 32734               20.0                 8.0                  30.0
# 33493               20.0                 8.0                  33.0
# 12678               20.0                 8.0                  33.0
# 38744               20.0                 8.0                  39.0
# 34054               20.0                 8.0                  39.0
# 10906               20.0                 8.0                  39.0
# 13115               20.0                 8.0                  39.0

# %%
# ap_data.set_index(ap_data['acctstarttime'], inplace = True)

# %%
# ap_data.head(5)

# %%
# 중복값 제거 (큐 이용)

queue1 = Queue()  #username 0
queue2 = Queue()  #acctstarttime  3
queue3 = Queue() #acctsessiontime   6
queue4 = Queue()  #index  1

minn = 0

for idx1, row1 in date_data.iterrows():
    queue1.queue = [] 
    queue2.queue = [] 
    queue3.queue = [] 
    queue4.queue = []
    print(" ")
    print(" ")
    print(" ")
    print("date_data : ", row1.date)
    for idx, row in ap_data.iterrows(): 
        print("idx : ", idx)
        timestamp = row.acctstarttime
        print("timestamp : ", timestamp)
        if row1.date.hour + 1 < row.acctstarttime.hour:
            break
            
        while(date_data.iat[idx1,0] < timestamp) and (timestamp < date_data.iat[idx1+1,0]):
            list = queue1.queue
            print("list : ", list)
#             coll = ap_data.iat[idx-1,1]
#             print("coll : ", coll)
#             print("username : ", ap_data.iloc[coll,])
#             print("username : ", ap_data.iat[idx-1,0])
            if ap_data.iat[idx-1,0] in list :
                print("중복!!")
                list1 = list_duplicates_of(queue1.queue, ap_data.iat[idx-1,0])
                print("list1 : ", list1)
                
                if ap_data.iat[idx,6] < queue3.queue[list1[0]]:
                    minn = ap_data.iat[idx-1,1]
                else:
                    minn = queue4.queue[list1[0]] 
                    
                #ap_data = ap_data[ap_data.number != minn]
                break
    
            print("헤이")
            queue1.push(ap_data.iat[idx-1,0])
            print("queue1 : ",queue1.queue)
            queue2.push(ap_data.iat[idx-1,3])
            print("queue2 : ",queue2.queue)
            queue3.push(ap_data.iat[idx-1,6])
            print("queue3 : ",queue3.queue)
            queue4.push(ap_data.iat[idx-1,1]) 
            print("queue4 : ",queue4.queue)
            break
# Out:
#
#
#
# date_data :  2019-09-20 00:00:00
# idx :  39457
# timestamp :  2019-09-20 07:32:00
#
#
#
# date_data :  2019-09-20 01:00:00
# idx :  39457
# timestamp :  2019-09-20 07:32:00
#
#
#
# date_data :  2019-09-20 02:00:00
# idx :  39457
# timestamp :  2019-09-20 07:32:00
#
#
#
# date_data :  2019-09-20 03:00:00
# idx :  39457
# timestamp :  2019-09-20 07:32:00
#
#
#
# date_data :  2019-09-20 04:00:00
# idx :  39457
# timestamp :  2019-09-20 07:32:00
#
#
#
# date_data :  2019-09-20 05:00:00
# idx :  39457
# timestamp :  2019-09-20 07:32:00
#
#
#
# date_data :  2019-09-20 06:00:00
# idx :  39457
# timestamp :  2019-09-20 07:32:00
# idx :  17997
# timestamp :  2019-09-20 07:32:00
# idx :  33702
# timestamp :  2019-09-20 08:09:00
#
#
#
# date_data :  2019-09-20 07:00:00
# idx :  39457
# timestamp :  2019-09-20 07:32:00
# list :  []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-d9908fd78635> in <module>
#      31 #             print("username : ", ap_data.iloc[coll,])
#      32 #             print("username : ", ap_data.iat[idx-1,0])
# ---> 33             if ap_data.iat[idx-1,0] in list :
#      34                 print("중복!!")
#      35                 list1 = list_duplicates_of(queue1.queue, ap_data.iat[idx-1,0])
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2173
#    2174         key = self._convert_key(key)
# -> 2175         return self.obj._get_value(*key, takeable=self._takeable)
#    2176
#    2177     def __setitem__(self, key, value):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    2819         if takeable:
#    2820             series = self._iget_item_cache(col)
# -> 2821             return com.maybe_box_datetimelike(series._values[index])
#    2822
#    2823         series = self._get_item_cache(col)
#
# IndexError: index 39456 is out of bounds for axis 0 with size 1824

# %%
# # 중복값 제거 (큐 이용)

# queue1 = Queue()  #username 0
# queue2 = Queue()  #acctstarttime  3
# queue3 = Queue() #acctsessiontime   6
# queue4 = Queue()  #index  1

# minn = 0

# for idx1, row1 in date_data.iterrows():
#     queue1.queue = [] 
#     queue2.queue = [] 
#     queue3.queue = [] 
#     queue4.queue = []
#     print("date_data : ", row1.date)
    
#     for idx, row in ap_data.iterrows(): 
#         print("idx : ", idx)
#         timestamp = row.acctstarttime
#         print("timestamp : ", timestamp)
        
#         while(date_data.iat[idx1,0] < timestamp) and (timestamp < date_data.iat[idx1+1,0]):
#             list = queue1.queue
#             print("list : ", list)
#             print("username : ", ap_data.iat[idx-1,0])
            
#             if ap_data.iat[idx-1,0] == 'nan':
#                 break
            
#             if ap_data.iat[idx-1,0] in list :
#                 print("중복!!")
#                 list1 = list_duplicates_of(queue1.queue, ap_data.iat[idx-1,0])
#                 print("list1 : ", list1)
                
#                 if ap_data.iat[idx,6] < queue3.queue[list1[0]]:
#                     minn = ap_data.iat[idx-1,1]
#                 else:
#                     minn = queue4.queue[list1[0]] 
                    
#                 ap_data[[ap_data['number'] == minn],:] = np.nan
#                 #ap_data = ap_data[ap_data.number != minn]
#                 break
      
#             print("헤이")
#             queue1.push(ap_data.iat[idx-1,0])
#             print("queue1 : ",queue1.queue)
#             queue2.push(ap_data.iat[idx-1,3])
#             print("queue2 : ",queue2.queue)
#             queue3.push(ap_data.iat[idx-1,6])
#             print("queue3 : ",queue3.queue)
#             queue4.push(ap_data.iat[idx-1,1]) 
#             print("queue4 : ",queue4.queue)
#             break

                
#             print("헤이")   
#             queue1.push(ap_data.iloc[idx,0])
#             print("queue1 : ",queue1.queue)
#             queue2.push(ap_data.iloc[idx,3])
#             print("queue2 : ",queue2.queue)
#             queue3.push(ap_data.iloc[idx,6])
#             print("queue3 : ",queue3.queue)
#             queue4.push(ap_data.iloc[idx,1]) 
#             print("queue4 : ",queue4.queue)
#             break

# %%
ap_data['acctstoptime'] =  pd.to_datetime(ap_data['acctstoptime'], infer_datetime_format=True)

# %%
ap_data['acctstarttime'] =  pd.to_datetime(ap_data['acctstarttime'], infer_datetime_format=True)

# %%
ap_data['acctstarttime_year'] = ap_data['acctstarttime'].dt.year
ap_data['acctstarttime_month'] = ap_data['acctstarttime'].dt.month
ap_data['acctstarttime_day'] = ap_data['acctstarttime'].dt.day
ap_data['acctstarttime_hour'] = ap_data['acctstarttime'].dt.hour
ap_data['acctstarttime_minute'] = ap_data['acctstarttime'].dt.minute

# %%
# # 중복값 제거 (큐 이용)

# queue1 = Queue()  #username 0
# queue2 = Queue()  #acctstarttime  3
# queue3 = Queue() #acctsessiontime   6
# queue4 = Queue()  #index  1

# minn = 0

# for idx1, row1 in date_data.iterrows():
#     queue1.queue = [] 
#     queue2.queue = [] 
#     queue3.queue = [] 
#     queue4.queue = []
#     print("date_data : ", row1.date)
    
#     for idx, row in ap_data.iterrows(): 
#         print("idx : ", idx)
#         timestamp = row.acctstarttime
#         print("timestamp : ", timestamp)
        
#         while(date_data.iat[idx1,0] < timestamp) and (timestamp < date_data.iat[idx1+1,0]):
#             list = queue1.queue
#             print("list : ", list)
#             print("username : ", ap_data.iat[idx-1,0])
#             if ap_data.iat[idx-1,0] in list :
#                 print("중복!!")
#                 list1 = list_duplicates_of(queue1.queue, ap_data.iat[idx-1,0])
#                 print("list1 : ", list1)
                
#                 if ap_data.iat[idx,6] < queue3.queue[list1[0]]:
#                     minn = ap_data.iat[idx-1,1]
#                 else:
#                     minn = queue4.queue[list1[0]] 
                    
#                 #ap_data = ap_data[ap_data.number != minn]
#                 break
    
#             print("헤이")
#             queue1.push(ap_data.iat[idx-1,0])
#             print("queue1 : ",queue1.queue)
#             queue2.push(ap_data.iat[idx-1,3])
#             print("queue2 : ",queue2.queue)
#             queue3.push(ap_data.iat[idx-1,6])
#             print("queue3 : ",queue3.queue)
#             queue4.push(ap_data.iat[idx-1,1]) 
#             print("queue4 : ",queue4.queue)
#             break
