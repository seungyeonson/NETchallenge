# %%
import tensorflow as tf
#Data Manipulation
import numpy as np
import pandas as pd

#Visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

#Importing Dependencies
# %matplotlib inline
# Out:
# /root/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /root/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /root/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
data = pd.read_excel('data/3월.xlsx')
data.head(3)
# Out:
#           id                                           username  pass  \
# 0  331078463  0x11257ED5B293F7ED9AA0A48677F9799A36477048F9A6...   NaN
# 1  331078468  0x98A165D4F1F5838C1C74D900BA1ED5C5041D0C2C2885...   NaN
# 2  331078469  0x98A165D4F1F5838C1C74D900BA1ED5C5041D0C2C2885...   NaN
#
#            reply            authdate requestipaddress  \
# 0  Access-Accept 2019-03-05 11:16:16     14.48.182.42
# 1  Access-Accept 2019-03-05 11:17:11  168.131.122.115
# 2  Access-Accept 2019-03-05 11:17:12  168.131.122.115
#
#              calledstationid   callingstationid  framedipaddress  \
# 0  06-30-0D-D1-DE-54:U_JNU-K  8C-8E-F2-11-38-A3              NaN
# 1          0E-30-0D-67-46-22  58-E2-8F-AA-77-23              NaN
# 2          0E-30-0D-67-46-22  58-E2-8F-AA-77-23              NaN
#
#    arubaessidname  arubalocationid
# 0             NaN              NaN
# 1             NaN              NaN
# 2             NaN              NaN

# %%
data.shape
# Out:
# (65640, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65640 entries, 0 to 65639
# Data columns (total 11 columns):
# id                  65640 non-null int64
# username            65640 non-null object
# pass                0 non-null float64
# reply               65640 non-null object
# authdate            65640 non-null datetime64[ns]
# requestipaddress    65640 non-null object
# calledstationid     65640 non-null object
# callingstationid    65640 non-null object
# framedipaddress     0 non-null float64
# arubaessidname      0 non-null float64
# arubalocationid     0 non-null float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(5)
# memory usage: 5.5+ MB

# %%
#framedipaddress, arubaessidname, arubalocationid가 쓸모없는 정보 이므로 삭제
data = data.drop(columns = ['framedipaddress'], axis = 1)
data = data.drop(columns = ['arubaessidname'], axis = 1)
data = data.drop(columns = ['arubalocationid'], axis = 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65640 entries, 0 to 65639
# Data columns (total 8 columns):
# id                  65640 non-null int64
# username            65640 non-null object
# pass                0 non-null float64
# reply               65640 non-null object
# authdate            65640 non-null datetime64[ns]
# requestipaddress    65640 non-null object
# calledstationid     65640 non-null object
# callingstationid    65640 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 4.0+ MB

# %%
#pass도 쓸모없는 null data 이므로 삭제
data = data.drop(columns = ['pass'], axis = 1)

# %%
data.info()
data.head(3)
data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65640 entries, 0 to 65639
# Data columns (total 7 columns):
# id                  65640 non-null int64
# username            65640 non-null object
# reply               65640 non-null object
# authdate            65640 non-null datetime64[ns]
# requestipaddress    65640 non-null object
# calledstationid     65640 non-null object
# callingstationid    65640 non-null object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 3.5+ MB
# (65640, 7)

# %%
data.head(3)
# Out:
#           id                                           username  \
# 0  331078463  0x11257ED5B293F7ED9AA0A48677F9799A36477048F9A6...
# 1  331078468  0x98A165D4F1F5838C1C74D900BA1ED5C5041D0C2C2885...
# 2  331078469  0x98A165D4F1F5838C1C74D900BA1ED5C5041D0C2C2885...
#
#            reply            authdate requestipaddress  \
# 0  Access-Accept 2019-03-05 11:16:16     14.48.182.42
# 1  Access-Accept 2019-03-05 11:17:11  168.131.122.115
# 2  Access-Accept 2019-03-05 11:17:12  168.131.122.115
#
#              calledstationid   callingstationid
# 0  06-30-0D-D1-DE-54:U_JNU-K  8C-8E-F2-11-38-A3
# 1          0E-30-0D-67-46-22  58-E2-8F-AA-77-23
# 2          0E-30-0D-67-46-22  58-E2-8F-AA-77-23

# %%
data.isnull().sum()
# Out:
# id                  0
# username            0
# reply               0
# authdate            0
# requestipaddress    0
# calledstationid     0
# callingstationid    0
# dtype: int64

# %%
data.groupby(['requestipaddress']).count()
# Out:
#                     id  username  reply  authdate  calledstationid  \
# requestipaddress
# 14.48.180.187     3778      3778   3778      3778             3778
# 14.48.180.189      615       615    615       615              615
# 14.48.180.190     5733      5733   5733      5733             5733
# 14.48.180.191     4955      4955   4955      4955             4955
# 14.48.180.192     1717      1717   1717      1717             1717
# ...                ...       ...    ...       ...              ...
# 168.131.122.129    287       287    287       287              287
# 168.131.122.130    239       239    239       239              239
# 168.131.122.131    517       517    517       517              517
# 168.131.122.132    499       499    499       499              499
# 168.131.13.221       1         1      1         1                1
#
#                   callingstationid
# requestipaddress
# 14.48.180.187                 3778
# 14.48.180.189                  615
# ...

# %%
data_1 = data.loc[(data['requestipaddress']=="168.131.122.113")|(data['requestipaddress']=="168.131.122.114")|(data['requestipaddress']=="168.131.122.115"),:]

# %%
data_1.head(10)
# Out:
#            id                                           username  \
# 1   331078468  0x98A165D4F1F5838C1C74D900BA1ED5C5041D0C2C2885...
# 2   331078469  0x98A165D4F1F5838C1C74D900BA1ED5C5041D0C2C2885...
# 7   331078477  0x98A165D4F1F5838C1C74D900BA1ED5C5041D0C2C2885...
# 8   331078478  0x98A165D4F1F5838C1C74D900BA1ED5C5041D0C2C2885...
# 20  331078508  0x9219F897804CF51ACB5B48F1BF8D5962DA4B0D04CBEE...
# 21  331078509  0x9219F897804CF51ACB5B48F1BF8D5962DA4B0D04CBEE...
# 22  331078511  0x9219F897804CF51ACB5B48F1BF8D5962DA4B0D04CBEE...
# 23  331078512  0x9219F897804CF51ACB5B48F1BF8D5962DA4B0D04CBEE...
# 46  331078562  0x9219F897804CF51ACB5B48F1BF8D5962DA4B0D04CBEE...
# 48  331078564  0x9219F897804CF51ACB5B48F1BF8D5962DA4B0D04CBEE...
#
#             reply            authdate requestipaddress    calledstationid  \
# 1   Access-Accept 2019-03-05 11:17:11  168.131.122.115  0E-30-0D-67-46-22
# 2   Access-Accept 2019-03-05 11:17:12  168.131.122.115  0E-30-0D-67-46-22
# ...

# %%
data_1.shape
# Out:
# (8415, 7)

# %%
data_113 = data_1.loc[(data['requestipaddress']=="168.131.122.113")]
data_114 = data_1.loc[(data['requestipaddress']=="168.131.122.114")]
data_115 = data_1.loc[(data['requestipaddress']=="168.131.122.115")]

# %%
data_113.head(10)
# Out:
#             id                                           username  \
# 20   331078508  0x9219F897804CF51ACB5B48F1BF8D5962DA4B0D04CBEE...
# 21   331078509  0x9219F897804CF51ACB5B48F1BF8D5962DA4B0D04CBEE...
# 70   331078602  0x976972E64E7E3C1F19E6089FF91A1B824057057D3299...
# 71   331078603  0x976972E64E7E3C1F19E6089FF91A1B824057057D3299...
# 76   331078609  0xE43B4E6154B337DFC65976774A9186429FAF9CEC058E...
# 77   331078610  0xE43B4E6154B337DFC65976774A9186429FAF9CEC058E...
# 82   331078619  0x976972E64E7E3C1F19E6089FF91A1B824057057D3299...
# 83   331078620  0x976972E64E7E3C1F19E6089FF91A1B824057057D3299...
# 102  331078645  0x0CEAB936E53C72E44EE8AA63CED8CDCE0C3FC8320E26...
# 116  331078680  0x976972E64E7E3C1F19E6089FF91A1B824057057D3299...
#
#              reply            authdate requestipaddress    calledstationid  \
# 20   Access-Accept 2019-03-05 11:22:54  168.131.122.113  0E-30-0D-67-46-D4
# 21   Access-Accept 2019-03-05 11:22:54  168.131.122.113  0E-30-0D-67-46-D4
# ...

# %%
data_113.to_excel('3월_113.xlsx',sheet_name='Sheet1')
data_114.to_excel('3월_114.xlsx',sheet_name='Sheet1')
data_115.to_excel('3월_115.xlsx',sheet_name='Sheet1')
