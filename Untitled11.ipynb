# %%
import pandas as pd
import numpy as np

# %%
# #radius_account

# columns = ['고유키','acctsessionid','acctuniqueid','사용자아이디','groupname','ap_ip','ap_port','ap_portt','사용시작시각',
#            '사용종료시각','사용시간(초)','acctauthentic','connectinfo_start','connectinfo_stop','입력 사용데이터','출력 사용데이터',
#            'ap_mac','단말기_mac','사용종료사유','servicetype','framedprotocol','단말기_ip','acctstartdelay','acctstopdelay','xascendsessionsvrkey']

# radius_account = pd.read_excel(r'C:\Users\user\radius_account\jnu_radius_account_03-06.xlsx', names = columns)
# radius_account = radius_account[['고유키','사w용자아이디','ap_ip','단말기_mac','사용시간(초)','사용시작시각']]

# # 기초특성화과학관 더 간단한 방법 생각

# radius_account = radius_account.loc[(radius_account['ap_ip']=='168.131.122.113')|(radius_account['ap_ip']=='168.131.122.114')|
# (radius_account['ap_ip']=='168.131.122.115')|(radius_account['ap_ip']=='168.131.122.116')|
# (radius_account['ap_ip']=='168.131.122.117')|(radius_account['ap_ip']=='168.131.122.118')|
# (radius_account['ap_ip']=='168.131.122.119')|(radius_account['ap_ip']=='168.131.122.120')|
# (radius_account['ap_ip']=='168.131.122.121')|(radius_account['ap_ip']=='168.131.122.122')|
# (radius_account['ap_ip']=='168.131.122.123')|(radius_account['ap_ip']=='168.131.122.124')|
# (radius_account['ap_ip']=='168.131.122.125')|(radius_account['ap_ip']=='168.131.122.126')|
# (radius_account['ap_ip']=='168.131.122.127')|(radius_account['ap_ip']=='168.131.122.128')|
# (radius_account['ap_ip']=='168.131.122.129')|(radius_account['ap_ip']=='168.131.122.130'),:]


# radius_account.set_index(radius_account['사용시작시각'], inplace=True)

# radius_account_df = radius_account.resample('5T', how={'all_num':np.sum}).fillna(0)

# radius_account.head(-1)


# radius_1층 = radius_account.loc[(radius_account['ap_ip']=='168.131.122.113')|(radius_account['ap_ip']=='168.131.122.114'),:]
# radius_2층 = radius_account.loc[(radius_account['ap_ip']=='168.131.122.115')|(radius_account['ap_ip']=='168.131.122.116'),:]
# radius_3층 = radius_account.loc[(radius_account['ap_ip']=='168.131.122.117')|(radius_account['ap_ip']=='168.131.122.118'),:]
# radius_4층 = radius_account.loc[(radius_account['ap_ip']=='168.131.122.119')|(radius_account['ap_ip']=='168.131.122.120'),:]
# radius_5층 = radius_account.loc[(radius_account['ap_ip']=='168.131.122.121')|(radius_account['ap_ip']=='168.131.122.122'),:]
# radius_6층 = radius_account.loc[(radius_account['ap_ip']=='168.131.122.123')|(radius_account['ap_ip']=='168.131.122.124'),:]
# radius_7층 = radius_account.loc[(radius_account['ap_ip']=='168.131.122.125')|(radius_account['ap_ip']=='168.131.122.126'),:]
# radius_8층 = radius_account.loc[(radius_account['ap_ip']=='168.131.122.127')|(radius_account['ap_ip']=='168.131.122.128'),:]
# radius_9층 = radius_account.loc[(radius_account['ap_ip']=='168.131.122.129')|(radius_account['ap_ip']=='168.131.122.130'),:]

# radius_1층['all_num'] = 1
# radius_2층['all_num'] = 1
# radius_3층['all_num'] = 1
# radius_4층['all_num'] = 1
# radius_5층['all_num'] = 1
# radius_6층['all_num'] = 1
# radius_7층['all_num'] = 1
# radius_8층['all_num'] = 1
# radius_9층['all_num'] = 1


# radius_1층.set_index(radius_1층['사용시작시각'], inplace=True)
# radius_1층_df = radius_1층.resample('30T', how={'all_num':np.sum}).fillna(0)
# radius_1층_df.head(-1)


# radius_2층.set_index(radius_account['사용시작시각'], inplace=True)
# radius_2층_df = radius_account.resample('30T', how={'all_num':np.sum}).fillna(0)
# radius_2층_df.head(-1)


# radius_3층.set_index(radius_account['사용시작시각'], inplace=True)
# radius_3층_df = radius_account.resample('30T', how={'all_num':np.sum}).fillna(0)
# radius_3층_df.head(-1)


# radius_4층.set_index(radius_account['사용시작시각'], inplace=True)
# radius_4층_df = radius_account.resample('30T', how={'all_num':np.sum}).fillna(0)
# radius_4층_df.head(-1)


# radius_5층.set_index(radius_account['사용시작시각'], inplace=True)
# radius_5층_df = radius_account.resample('30T', how={'all_num':np.sum}).fillna(0)
# radius_5층_df.head(-1)


# radius_6층.set_index(radius_account['사용시작시각'], inplace=True)
# radius_6층_df = radius_account.resample('30T', how={'all_num':np.sum}).fillna(0)
# radius_6층_df.head(-1)


# 자연대

# radius_account = radius_account.loc[(radius_account['ap_ip']=='14.48.182.42')|(radius_account['ap_ip']=='14.48.182.43')|
# (radius_account['ap_ip']=='14.48.182.44')|(radius_account['ap_ip']=='14.48.182.52')|
# (radius_account['ap_ip']=='14.48.182.45')|(radius_account['ap_ip']=='14.48.182.53')|
# (radius_account['ap_ip']=='14.48.182.46')|(radius_account['ap_ip']=='14.48.182.54')|
# (radius_account['ap_ip']=='14.48.182.47')|(radius_account['ap_ip']=='14.48.182.55')|
# (radius_account['ap_ip']=='14.48.182.48')|(radius_account['ap_ip']=='14.48.182.56')|
# (radius_account['ap_ip']=='14.48.182.49')|(radius_account['ap_ip']=='14.48.182.57')|
# (radius_account['ap_ip']=='14.48.182.50')|(radius_account['ap_ip']=='14.48.182.51'),:]


# radius_account['all_num'] = 1

# radius_account.set_index(radius_account['사용시작시각'], inplace=True)

# radius_account_df = radius_account.resample('30T', how={'all_num':np.sum}).fillna(0)

# radius_account_df.head(-1)
# 자연대 행 수 : 5802
# Out:
#   File "<ipython-input-35-4af327e71e71>", line 100
#     자연대 행 수 : 5802
#         ^
# SyntaxError: invalid syntax

# %%
# radius_authenfication

# columns = ['고유키','사용자아이디','pass','인증여부','인증시각','ap_ip','ap_mac',
#            '단말기_mac','framedipaddress','arubaessidname','arubalocationid']

# radius_auth_3 = pd.read_excel(r'C:\Users\user\radius_authenfication\3월.xlsx', names = columns)
# radius_auth_3 = radius_auth_3[['사용자아이디','인증여부','인증시각','ap_ip','ap_mac','단말기_mac']]

# radius_auth_4 = pd.read_excel(r'C:\Users\user\radius_authenfication\4월.xlsx', names = columns)
# radius_auth_4 = radius_auth_4[['사용자아이디','인증여부','인증시각','ap_ip','ap_mac','단말기_mac']]
                               
# radius_auth_5 = pd.read_excel(r'C:\Users\user\radius_authenfication\5월.xlsx', names = columns)
# radius_auth_5 = radius_auth_5[['사용자아이디','인증여부','인증시각','ap_ip','ap_mac','단말기_mac']]
             
# radius_auth_6 = pd.read_excel(r'C:\Users\user\radius_authenfication\6월.xlsx', names = columns)
# radius_auth_6 = radius_auth_6[['사용자아이디','인증여부','인증시각','ap_ip','ap_mac','단말기_mac']]


# #행에 데이터 추가 

# radius_auth_df = radius_auth_3.append(radius_auth_4)
# radius_auth_df = radius_auth_df.append(radius_auth_5)
# radius_auth_df = radius_auth_df.append(radius_auth_6)

# # 기초특성화과학관 더 간단한 방법 생각
# radius_auth_df = radius_auth_df.loc[(radius_auth_df['ap_ip']=='168.131.122.113')|(radius_auth_df['ap_ip']=='168.131.122.114')|
# (radius_auth_df['ap_ip']=='168.131.122.115')|(radius_auth_df['ap_ip']=='168.131.122.116')|
# (radius_auth_df['ap_ip']=='168.131.122.117')|(radius_auth_df['ap_ip']=='168.131.122.118')|
# (radius_auth_df['ap_ip']=='168.131.122.119')|(radius_auth_df['ap_ip']=='168.131.122.120')|
# (radius_auth_df['ap_ip']=='168.131.122.121')|(radius_auth_df['ap_ip']=='168.131.122.122')|
# (radius_auth_df['ap_ip']=='168.131.122.123')|(radius_auth_df['ap_ip']=='168.131.122.124')|
# (radius_auth_df['ap_ip']=='168.131.122.125')|(radius_auth_df['ap_ip']=='168.131.122.126')|
# (radius_auth_df['ap_ip']=='168.131.122.127')|(radius_auth_df['ap_ip']=='168.131.122.128')|
# (radius_auth_df['ap_ip']=='168.131.122.129')|(radius_auth_df['ap_ip']=='168.131.122.130'),:]

# #radius_auth_df.head(-1) 51789개

# %%
import pandas as pd
import numpy as np
import datetime

# %%
# 공기질 데이터 5분마다 나눠져 

air_df5 = pd.read_excel(r'C:\Users\user\넷첼린지\air_status\air5.xls' )
air_df6 = pd.read_excel(r'C:\Users\user\넷첼린지\air_status\air6.xls' )

air_df = pd.concat([air_df5, air_df6] , axis=0)

# 기초특성화과학관-1층

air_df1 = air_df[['시간','자연대(이산화탄소)','자연대(온도 ℃)','자연대(습도 %)']]

air_df1['시간'] = pd.to_datetime(air_df1['시간']) 

air_df1.set_index(air_df1['시간'], inplace=True)

air_df1 = air_df1.resample('15T', how={'자연대(이산화탄소)':np.average,'자연대(온도 ℃)':np.average, '자연대(습도 %)':np.average}).fillna(0)



# 명학회관-4층
air_df2 = air_df[['시간','도서관(이산화탄소)','도서관(온도 ℃)','도서관(습도 %)']]

air_df2['시간'] = pd.to_datetime(air_df2['시간']) 

air_df2.set_index(air_df2['시간'], inplace=True)

air_df2 = air_df2.resample('15T', how={'도서관(이산화탄소)':np.average,'도서관(온도 ℃)':np.average, '도서관(습도 %)':np.average}).fillna(0)


#air_df 행 수 :5855개
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   app.launch_new_instance()
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
ap_df1 = pd.read_excel('기초특성화과학관ap56.xlsx')
ap_df1.set_index(ap_df1['date_5_6'], inplace=True)

result = pd.concat([ap_df1,air_df1], axis = 1)

# %%
result=result.drop('Unnamed: 0',axis=1)
result=result.reset_index(drop=True)

# %%
result.head(-1)
# Out:
#                 date_5_6  all_num  자연대(이산화탄소)  자연대(온도 ℃)  자연대(습도 %)
# 0    2019-05-01 00:00:00        0  528.000000  39.500000  20.100000
# 1    2019-05-01 00:15:00        2  547.666667  39.633333  20.100000
# 2    2019-05-01 00:30:00        0  536.666667  39.666667  20.100000
# 3    2019-05-01 00:45:00        0  518.333333  39.633333  20.100000
# 4    2019-05-01 01:00:00        0  534.333333  39.666667  20.100000
# 5    2019-05-01 01:15:00        0  542.000000  39.700000  20.100000
# 6    2019-05-01 01:30:00        0  521.666667  39.633333  20.100000
# 7    2019-05-01 01:45:00        0  545.333333  39.700000  20.100000
# 8    2019-05-01 02:00:00        0  524.666667  39.666667  20.100000
# 9    2019-05-01 02:15:00        0  528.333333  39.666667  20.100000
# 10   2019-05-01 02:30:00        0  523.000000  39.600000  20.100000
# 11   2019-05-01 02:45:00        0  524.000000  39.666667  20.100000
# 12   2019-05-01 03:00:00        0  540.333333  39.633333  20.100000
# ...

# %%
result.to_excel('기초특성화과학관1_56.xlsx',sheet_name='Sheet1')

# %%
#명학회관

ap_df2 = pd.read_excel('명학회관4ap56.xlsx')
ap_df2.set_index(ap_df2['date_5_6'], inplace=True)
result1 = pd.concat([ap_df2,air_df2], axis=1)

# %%
result1=result1.drop('Unnamed: 0',axis=1)
result1=result1.reset_index(drop=True)

# %%
result1.head(-1)
# Out:
#                 date_5_6  all_num  도서관(이산화탄소)  도서관(온도 ℃)  도서관(습도 %)
# 0    2019-05-01 00:00:00        0  754.000000  26.400000  30.533333
# 1    2019-05-01 00:15:00        0  748.666667  26.266667  31.366667
# 2    2019-05-01 00:30:00        0  743.000000  26.433333  30.933333
# 3    2019-05-01 00:45:00        0  737.333333  26.433333  30.566667
# 4    2019-05-01 01:00:00        2  729.666667  26.433333  31.233333
# 5    2019-05-01 01:15:00        2  700.666667  26.366667  31.200000
# 6    2019-05-01 01:30:00        2  698.000000  26.466667  30.566667
# 7    2019-05-01 01:45:00        2  690.333333  26.533333  30.633333
# 8    2019-05-01 02:00:00        2  706.333333  26.400000  31.200000
# 9    2019-05-01 02:15:00        2  676.666667  26.433333  30.666667
# 10   2019-05-01 02:30:00        2  674.666667  26.466667  30.466667
# 11   2019-05-01 02:45:00        4  667.333333  26.333333  31.200000
# 12   2019-05-01 03:00:00        2  669.000000  26.366667  30.833333
# ...

# %%
result.to_excel('명학회관4_56.xlsx',sheet_name='Sheet1')

# %%
#기초특성화과학관-1층

ap_df = pd.read_excel('ap.xlsx',sheet_name='AP사용정보')

ap_df = ap_df.loc[(ap_df['AP가 설치된 건물-층']=="기초특성화과학관-1층"),:]
ap_df.set_index(ap_df['START_USING_TIME'], inplace=True)

ap_df = ap_df.resample('15T', how={'AP가 설치된 건물-층','USAGE_TIME(second)'}).fillna(0)
ap_df['all_num'] = 0
ap_df.head(50)

#명학회관-4층

# ap_df = pd.read_excel('ap.xlsx',sheet_name='AP사용정보')
# ap_df = ap_df.loc[(ap_df['AP가 설치된 건물-층']=="명학회관-4층"),:]
# ap_df.set_index(radius_account['사용시작시각'], inplace=True)
# ap_df = radius_account.resample('15T', how={'AP가 설치된 건물-층','USAGE_TIME(second)'}).fillna(0)
# ap_df['all_num'] = 0

#ap_df.head(50)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-836f78936371> in <module>
#       6 ap_df.set_index(ap_df['START_USING_TIME'], inplace=True)
#       7
# ----> 8 ap_df = ap_df.resample('15T', how={'AP가 설치된 건물-층','USAGE_TIME(second)'}).fillna(0)
#       9 ap_df['all_num'] = 0
#      10 ap_df.head(50)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    8157                                            how=how,
#    8158                                            fill_method=fill_method,
# -> 8159                                            limit=limit)
#    8160
# ...

# %%
#명학회관

air_df2 = air_df2
ap_df2 = pd.read_excel('명학회관4ap56.xlsx')


result1 = pd.concat('ap_df2','air_df2')

# %%
result.describe()

#두달 간의 데이터가 있고, 평균은 4명, 최대는 245이다
#50%의 데이터가 6이므로 3단계로 잡았다
#75%가 14이므로 4단계 그 위는 무조건 5단계이다

result.loc[result.all_num > 7, 'class'] = 5
result.loc[result.all_num <= 7, 'class'] = 4 
result.loc[result.all_num <= 2, 'class'] = 3
result.loc[result.all_num <= 1, 'class'] = 2 
result.loc[result.all_num <= 0, 'class'] = 1 

result.head(10)
# Out:
#                      all_num  자연대(이산화탄소)  자연대(온도 ℃)  자연대(습도 %)      pca_x  \
# 시간
# 2019-03-01 12:30:00      3.0  523.166667  29.916667  22.866667  -8.997061
# 2019-03-01 13:00:00      0.0  520.333333  29.983333  23.116667  -4.928552
# 2019-03-01 13:30:00      0.0  530.333333  30.016667  23.083333 -18.996435
# 2019-03-01 14:00:00      0.0  517.666667  29.983333  22.983333  -1.179465
# 2019-03-01 14:30:00      0.0  496.166667  30.016667  22.950000  29.050352
# 2019-03-01 15:00:00      0.0  503.333333  30.033333  23.050000  18.970339
# 2019-03-01 15:30:00      0.0  497.833333  30.050000  23.000000  26.702052
# 2019-03-01 16:00:00      0.0  511.333333  30.100000  22.983333   7.709887
# 2019-03-01 16:30:00      0.0  508.166667  30.066667  22.983333  12.167970
# 2019-03-01 17:00:00      0.0  508.666667  30.033333  22.983333  11.469708
#
#                         pca_y  class
# 시간
# 2019-03-01 12:30:00 -2.032625    4.0
# 2019-03-01 13:00:00 -6.190068    1.0
# ...

# %%
from sklearn.preprocessing import scale
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)
pca_transformed = pca.fit_transform(result)

result['pca_x'] = pca_transformed[:,0]
result['pca_y'] = pca_transformed[:,1]
result.head(3)
# Out:
#                      all_num  자연대(이산화탄소)  자연대(온도 ℃)  자연대(습도 %)      pca_x  \
# 시간
# 2019-03-01 12:30:00      3.0  523.166667  29.916667  22.866667  -8.997061
# 2019-03-01 13:00:00      0.0  520.333333  29.983333  23.116667  -4.928552
# 2019-03-01 13:30:00      0.0  530.333333  30.016667  23.083333 -18.996435
#
#                         pca_y
# 시간
# 2019-03-01 12:30:00 -2.032625
# 2019-03-01 13:00:00 -6.190068
# 2019-03-01 13:30:00 -6.154713

# %%
marker1_ind = result[result['class']==1].index
marker2_ind = result[result['class']==2].index
marker3_ind = result[result['class']==3].index
marker4_ind = result[result['class']==4].index
marker5_ind = result[result['class']==5].index

plt.scatter(x = result.loc[marker1_ind, 'pca_x'], y = result.loc[marker1_ind, 'pca_y'], marker = 'o')
plt.scatter(x = result.loc[marker2_ind, 'pca_x'], y = result.loc[marker2_ind, 'pca_y'], marker = 's')
plt.scatter(x = result.loc[marker3_ind, 'pca_x'], y = result.loc[marker3_ind, 'pca_y'], marker = '^')
plt.scatter(x = result.loc[marker4_ind, 'pca_x'], y = result.loc[marker4_ind, 'pca_y'], marker = 'P')
plt.scatter(x = result.loc[marker5_ind, 'pca_x'], y = result.loc[marker5_ind, 'pca_y'], marker = 'D')

plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('5 cluster')
plt.show()

# %%
#군집 평가

from sklearn.metrics import silhouette_samples, silhouette_score

score_samples
