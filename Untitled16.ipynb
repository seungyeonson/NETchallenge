# %%
import tensorflow as tf
#Data Manipulation
import numpy as np
import pandas as pd

#Visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

#Importing Dependencies
# %matplotlib inline

import math
# Out:
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
#액셀파일 열기
data = pd.read_excel('ap_data/ap.xlsx',sheet_name='AP사용정보')
data.head(3)
# Out:
#   USER_TYPE     AP IP주소 AP가 설치된 건물-층                  위도,경도 AP_TYPE  \
# 0        학생  168.131***  기초특성화과학관-7층  35.175860, 126.911051   전남대AP
# 1        학생  168.131***  기초특성화과학관-1층  35.175860, 126.911051   전남대AP
# 2        학생  14.48.1***      명학회관-4층  35.141651, 126.923151   통신사AP
#
#      START_USING_TIME      END_USING_TIME  USAGE_TIME(second)  \
# 0 2019-05-01 00:21:43 2019-05-01 01:06:38                2693
# 1 2019-05-01 00:28:32 2019-05-01 00:29:06                  34
# 2 2019-05-01 01:09:34 2019-05-01 01:12:17                 162
#
#   AP_MAC -SHA256해쉬값전환 사용자단말 MAC-SHA256해쉬값전환
# 0               qqGqT                 1V/2G
# 1               9REc7                 iA07F
# 2               LbvpW                 MJj9o

# %%
data_ap = data.loc[(data['AP가 설치된 건물-층']=="명학회관-4층"),:]
data_ap.head(50)
# Out:
#     USER_TYPE     AP IP주소 AP가 설치된 건물-층                  위도,경도 AP_TYPE  \
# 2          학생  14.48.1***      명학회관-4층  35.141651, 126.923151   통신사AP
# 3          학생  14.48.1***      명학회관-4층  35.141651, 126.923151   통신사AP
# 5          학생  14.48.1***      명학회관-4층  35.141651, 126.923151   통신사AP
# 7          학생  14.48.1***      명학회관-4층  35.141651, 126.923151   통신사AP
# 9          학생  14.48.1***      명학회관-4층  35.141651, 126.923151   통신사AP
# 13         학생  14.48.1***      명학회관-4층  35.141651, 126.923151   통신사AP
# 15         학생  14.48.1***      명학회관-4층  35.141651, 126.923151   통신사AP
# 30         학생  14.48.1***      명학회관-4층  35.141651, 126.923151   통신사AP
# 31         학생  14.48.1***      명학회관-4층  35.141651, 126.923151   통신사AP
# 35         학생  14.48.1***      명학회관-4층  35.141651, 126.923151   통신사AP
# 188        학생  14.48.1***      명학회관-4층  35.141651, 126.923151   통신사AP
# 190        학생  14.48.1***      명학회관-4층  35.141651, 126.923151   통신사AP
# ...

# %%
data_ap.dtypes
# Out:
# USER_TYPE                        object
# AP IP주소                          object
# AP가 설치된 건물-층                     object
# 위도,경도                            object
# AP_TYPE                          object
# START_USING_TIME         datetime64[ns]
# END_USING_TIME           datetime64[ns]
# USAGE_TIME(second)                int64
# AP_MAC -SHA256해쉬값전환              object
# 사용자단말 MAC-SHA256해쉬값전환            object
# dtype: object
