# %%
import pandas as pd
import numpy as np

# %%
ap_data = pd.read_excel("air_log_7.xlsx")

# %%
ap_data
# Out:
#      Unnamed: 0                date  all_num    temp   humid       co2  \
# 0             0 2019-09-20 00:00:00        1  25.825  41.575  4241.525
# 1             1 2019-09-20 01:00:00        0  25.975  42.825  3801.725
# 2             2 2019-09-20 02:00:00        0  26.100  43.450  3427.850
# 3             3 2019-09-20 03:00:00        0  25.750  46.225  2392.275
# 4             4 2019-09-20 04:00:00        0  25.450  48.350  1088.625
# ..          ...                 ...      ...     ...     ...       ...
# 980         980 2019-10-30 20:00:00       25  26.825  45.900  2446.600
# 981         981 2019-10-30 21:00:00       38  27.100  46.475  2586.450
# 982         982 2019-10-30 22:00:00       28  27.125  45.250  2231.200
# 983         983 2019-10-30 23:00:00       23  27.025  45.125  2155.050
# 984         984 2019-10-31 00:00:00        0  26.750  43.600  1790.125
#
#          voc  pm25    light   noise  강수량  비    기온   풍속  date_day  date_hour  \
# ...

# %%
ap_data.describe()
# Out:
#        Unnamed: 0     all_num        temp       humid          co2  \
# count  985.000000  985.000000  985.000000  985.000000   985.000000
# mean   492.000000   13.072081   25.760964   48.289416  1641.462487
# std    284.489309   11.345636    3.319216    8.572134  1309.777256
# min      0.000000    0.000000    0.000000    0.000000     0.000000
# 25%    246.000000    1.000000   25.150000   43.900000   669.800000
# 50%    492.000000   12.000000   26.125000   48.650000  1190.425000
# 75%    738.000000   22.000000   27.025000   53.775000  2116.025000
# max    984.000000   50.000000   34.175000   67.500000  5000.000000
#
#               voc   pm25        light       noise         강수량           비  \
# count  985.000000  985.0   985.000000  985.000000  985.000000  985.000000
# mean   271.755939    0.0   324.222665   51.149010    0.258579    0.084264
# std    155.490411    0.0   205.041090    6.012754    1.294426    0.277924
# ...

# %%
real_data = pd.read_excel("real_counting.xlsx",sheet_name = '7')

# %%
ap_data = pd.concat([ap_data,real_data], axis = 1)

# %%
ap_data.describe()
# Out:
#        Unnamed: 0     all_num        temp       humid          co2  \
# count  985.000000  985.000000  985.000000  985.000000   985.000000
# mean   492.000000   13.072081   25.760964   48.289416  1641.462487
# std    284.489309   11.345636    3.319216    8.572134  1309.777256
# min      0.000000    0.000000    0.000000    0.000000     0.000000
# 25%    246.000000    1.000000   25.150000   43.900000   669.800000
# 50%    492.000000   12.000000   26.125000   48.650000  1190.425000
# 75%    738.000000   22.000000   27.025000   53.775000  2116.025000
# max    984.000000   50.000000   34.175000   67.500000  5000.000000
#
#               voc   pm25        light       noise         강수량           비  \
# count  985.000000  985.0   985.000000  985.000000  985.000000  985.000000
# mean   271.755939    0.0   324.222665   51.149010    0.258579    0.084264
# std    155.490411    0.0   205.041090    6.012754    1.294426    0.277924
# ...

# %%
ap_data = ap_data[:576]

# %%
ap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 21 columns):
# Unnamed: 0      576 non-null int64
# date            576 non-null datetime64[ns]
# all_num         576 non-null int64
# temp            576 non-null float64
# humid           576 non-null float64
# co2             576 non-null float64
# voc             576 non-null float64
# pm25            576 non-null int64
# light           576 non-null float64
# noise           576 non-null float64
# 강수량             576 non-null float64
# 비               576 non-null int64
# 기온              576 non-null float64
# 풍속              576 non-null float64
# date_day        576 non-null int64
# date_hour       576 non-null int64
# date_minute     576 non-null int64
# date_weekday    576 non-null int64
# 날짜              576 non-null datetime64[ns]
# 시간              576 non-null float64
# real_number     576 non-null float64
# dtypes: datetime64[ns](2), float64(11), int64(8)
# ...

# %%
ap_data = ap_data.drop(['Unnamed: 0','humid','co2','pm25','noise','비', 'date_weekday' ,'date_minute'], axis = 1)
ap_data.set_index(ap_data['date'], inplace=True)

# %%
ap_data
# Out:
#                                    date  all_num    temp      voc    light  \
# date
# 2019-09-20 00:00:00 2019-09-20 00:00:00        1  25.825  525.225  126.975
# 2019-09-20 01:00:00 2019-09-20 01:00:00        0  25.975  506.225    0.000
# 2019-09-20 02:00:00 2019-09-20 02:00:00        0  26.100  486.750    0.000
# 2019-09-20 03:00:00 2019-09-20 03:00:00        0  25.750  379.825  160.750
# 2019-09-20 04:00:00 2019-09-20 04:00:00        0  25.450  223.500    0.000
# ...                                 ...      ...     ...      ...      ...
# 2019-10-13 19:00:00 2019-10-13 19:00:00        6   0.000    0.000    0.000
# 2019-10-13 20:00:00 2019-10-13 20:00:00        4   0.000    0.000    0.000
# 2019-10-13 21:00:00 2019-10-13 21:00:00        0   0.000    0.000    0.000
# 2019-10-13 22:00:00 2019-10-13 22:00:00        0   0.000    0.000    0.000
# 2019-10-13 23:00:00 2019-10-13 23:00:00        0   0.000    0.000    0.000
#
# ...

# %%
ap_data.describe()
# Out:
#           all_num        temp         voc       light         강수량          기온  \
# count  576.000000  576.000000  576.000000  576.000000  576.000000  576.000000
# mean    11.076389   25.890929  278.441450  301.160286    0.435069   19.926042
# std     10.401224    2.723338  169.938187  204.795671    1.665701    3.799618
# min      0.000000    0.000000    0.000000    0.000000    0.000000    9.500000
# 25%      0.000000   25.300000  139.268750  105.575000    0.000000   17.075000
# 50%     10.000000   26.025000  262.150000  344.587500    0.000000   19.900000
# 75%     19.000000   26.825000  414.225000  397.400000    0.000000   22.400000
# max     43.000000   34.175000  776.200000  866.650000   20.000000   28.400000
#
#                풍속   date_day   date_hour          시간  real_number
# count  576.000000  576.00000  576.000000  576.000000   576.000000
# mean     1.546875   15.25000   11.500000   11.500000    24.828125
# std      1.587283    9.63147    6.928203    6.928203    22.142227
# ...

# %%
ap_data.isnull().sum()
# Out:
# date           0
# all_num        0
# temp           0
# voc            0
# light          0
# 강수량            0
# 기온             0
# 풍속             0
# date_day       0
# date_hour      0
# 날짜             0
# 시간             0
# real_number    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (30,15))
xticks = pd.date_range(start = '2019-09-20', end ='2019-10-31')
week  = ["일","월","화","수","목","금","토"]
xticks_name = [week[int(w)]+d for w, d in zip(xticks.strftime("%w"),
                                             xticks.strftime(" %m-%d"))]
plt.xticks(xticks,xticks_name , rotation = 90, ha = "left")
plt.plot(ap_data['all_num'],linewidth = 1)
plt.xlabel("날짜")
plt.ylabel("대여횟수")
# Out:
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\pandas\plotting\_matplotlib\converter.py:102: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, '대여횟수')
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 53664 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
ap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 576 entries, 2019-09-20 00:00:00 to 2019-10-13 23:00:00
# Data columns (total 13 columns):
# date           576 non-null datetime64[ns]
# all_num        576 non-null int64
# temp           576 non-null float64
# voc            576 non-null float64
# light          576 non-null float64
# 강수량            576 non-null float64
# 기온             576 non-null float64
# 풍속             576 non-null float64
# date_day       576 non-null int64
# date_hour      576 non-null int64
# 날짜             576 non-null datetime64[ns]
# 시간             576 non-null float64
# real_number    576 non-null float64
# dtypes: datetime64[ns](2), float64(8), int64(3)
# memory usage: 63.0 KB

# %%
# ap_data = ap_data[:576]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (30,15))
xticks = pd.date_range(start = '2019-09-20', end ='2019-10-31')
week  = ["일","월","화","수","목","금","토"]
xticks_name = [week[int(w)]+d for w, d in zip(xticks.strftime("%w"),
                                             xticks.strftime(" %m-%d"))]
plt.xticks(xticks,xticks_name , rotation = 90, ha = "left")
plt.plot(ap_data['real_number'],linewidth = 1)
plt.xlabel("날짜")
plt.ylabel("대여횟수")
# Out:
# Text(0, 0.5, '대여횟수')

# %%
from sklearn.preprocessing import minmax_scale

df = pd.DataFrame()
df['date'] = ap_data['date']
df['all_num'] = minmax_scale(ap_data['all_num'], axis=0, copy=True)
df['real_number'] = minmax_scale(ap_data['real_number'], axis=0, copy=True)
df['temp'] = minmax_scale(ap_data['temp'], axis=0, copy=True)
df['voc'] = minmax_scale(ap_data['voc'], axis=0, copy=True)
df['light'] = minmax_scale(ap_data['light'], axis=0, copy=True)
df['hour'] = minmax_scale(ap_data['date_hour'], axis=0, copy=True)
df['강수량'] = minmax_scale(ap_data['강수량'], axis=0, copy=True)
df['기온'] = minmax_scale(ap_data['기온'], axis=0, copy=True)
df['풍속'] = minmax_scale(ap_data['풍속'], axis=0, copy=True)
df['day'] = minmax_scale(ap_data['date_day'], axis=0, copy=True)
df['hour'] = minmax_scale(ap_data['date_hour'], axis=0, copy=True)
df.set_index(df['date'], inplace=True)

# %%
df
# Out:
#                                    date   all_num  real_number      temp  \
# date
# 2019-09-20 00:00:00 2019-09-20 00:00:00  0.023256     0.000000  0.755669
# 2019-09-20 01:00:00 2019-09-20 01:00:00  0.000000     0.000000  0.760059
# 2019-09-20 02:00:00 2019-09-20 02:00:00  0.000000     0.000000  0.763716
# 2019-09-20 03:00:00 2019-09-20 03:00:00  0.000000     0.000000  0.753475
# 2019-09-20 04:00:00 2019-09-20 04:00:00  0.000000     0.000000  0.744696
# ...                                 ...       ...          ...       ...
# 2019-10-13 19:00:00 2019-10-13 19:00:00  0.139535     0.576923  0.000000
# 2019-10-13 20:00:00 2019-10-13 20:00:00  0.093023     0.641026  0.000000
# 2019-10-13 21:00:00 2019-10-13 21:00:00  0.000000     0.576923  0.000000
# 2019-10-13 22:00:00 2019-10-13 22:00:00  0.000000     0.282051  0.000000
# 2019-10-13 23:00:00 2019-10-13 23:00:00  0.000000     0.153846  0.000000
#
#                           voc     light      hour  강수량        기온        풍속  \
# date
# ...

# %%
# df['minute'] = minmax_scale(ap_data['date_minute'], axis=0, copy=True)
# df['비'] = minmax_scale(ap_data['비'], axis=0, copy=True)
# df['humid'] = minmax_scale(ap_data['humid'], axis=0, copy=True)
# df['co2'] = minmax_scale(ap_data['co2'], axis=0, copy=True)
# df['noise'] = minmax_scale(ap_data['noise'], axis=0, copy=True)

# %%
df
# Out:
#                                    date   all_num  real_number      temp  \
# date
# 2019-09-20 00:00:00 2019-09-20 00:00:00  0.023256     0.000000  0.755669
# 2019-09-20 01:00:00 2019-09-20 01:00:00  0.000000     0.000000  0.760059
# 2019-09-20 02:00:00 2019-09-20 02:00:00  0.000000     0.000000  0.763716
# 2019-09-20 03:00:00 2019-09-20 03:00:00  0.000000     0.000000  0.753475
# 2019-09-20 04:00:00 2019-09-20 04:00:00  0.000000     0.000000  0.744696
# ...                                 ...       ...          ...       ...
# 2019-10-13 19:00:00 2019-10-13 19:00:00  0.139535     0.576923  0.000000
# 2019-10-13 20:00:00 2019-10-13 20:00:00  0.093023     0.641026  0.000000
# 2019-10-13 21:00:00 2019-10-13 21:00:00  0.000000     0.576923  0.000000
# 2019-10-13 22:00:00 2019-10-13 22:00:00  0.000000     0.282051  0.000000
# 2019-10-13 23:00:00 2019-10-13 23:00:00  0.000000     0.153846  0.000000
#
#                           voc     light      hour  강수량        기온        풍속  \
# date
# ...

# %%
X = df.index.astype("int64").values.reshape(-1,1)
y = df['real_number']

# %%
X
# Out:
# array([[1568937600000000000],
#        [1568941200000000000],
#        [1568944800000000000],
#        [1568948400000000000],
#        [1568952000000000000],
#        [1568955600000000000],
#        [1568959200000000000],
#        [1568962800000000000],
#        [1568966400000000000],
#        [1568970000000000000],
#        [1568973600000000000],
#        [1568977200000000000],
#        [1568980800000000000],
#        [1568984400000000000],
#        [1568988000000000000],
#        [1568991600000000000],
#        [1568995200000000000],
#        [1568998800000000000],
#        [1569002400000000000],
#        [1569006000000000000],
#        [1569009600000000000],
#        [1569013200000000000],
#        [1569016800000000000],
#        [1569020400000000000],
#        [1569024000000000000],
#        [1569027600000000000],
#        [1569031200000000000],
#        [1569034800000000000],
#        [1569038400000000000],
#        [1569042000000000000],
#        [1569045600000000000],
# ...

# %%
y
# Out:
# date
# 2019-09-20 00:00:00    0.000000
# 2019-09-20 01:00:00    0.000000
# 2019-09-20 02:00:00    0.000000
# 2019-09-20 03:00:00    0.000000
# 2019-09-20 04:00:00    0.000000
#                          ...
# 2019-10-13 19:00:00    0.576923
# 2019-10-13 20:00:00    0.641026
# 2019-10-13 21:00:00    0.576923
# 2019-10-13 22:00:00    0.282051
# 2019-10-13 23:00:00    0.153846
# Name: real_number, Length: 576, dtype: float64

# %%
y.isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 576 entries, 2019-09-20 00:00:00 to 2019-10-13 23:00:00
# Data columns (total 11 columns):
# date           576 non-null datetime64[ns]
# all_num        576 non-null float64
# real_number    576 non-null float64
# temp           576 non-null float64
# voc            576 non-null float64
# light          576 non-null float64
# hour           576 non-null float64
# 강수량            576 non-null float64
# 기온             576 non-null float64
# 풍속             576 non-null float64
# day            576 non-null float64
# dtypes: datetime64[ns](1), float64(10)
# memory usage: 54.0 KB

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import VotingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import svm

n_train = 24*17
y_t = []
y_p = []
y_tr = []

def eval_on_features(features, target, regressor):
    X_train,X_test = features[:n_train], features[n_train:]
    y_train, y_test = target[:n_train], target[n_train:]
    y_t.append(y_test)
    y_tr.append(y_train)
    regressor.fit(X_train,y_train)
    print("훈련 세트 R^2: {:.2f}".format(regressor.score(X_train, y_train)))
    print("테스트 세트 R^2: {:.2f}".format(regressor.score(X_test, y_test)))
    y_pred =minmax_scale( regressor.predict(X_test))
    y_pred_train = minmax_scale(regressor.predict(X_train))
    y_p.append(y_pred)
    plt.figure(figsize = (15,10))
    
    plt.xticks(range(0, len(X), 14), xticks_name, rotation = 300, ha="left")
    
    plt.plot(range(n_train), y_train, label = "train")
    #plt.plot(range(n_train, len(y_test) +  n_train), y_test, '-', label = "test")
    plt.plot(range(n_train), y_pred_train, '--', label = "train_predict")
    
    plt.plot(range(n_train, len(y_test) + n_train), y_pred, '--', label = 'test_predict')
    plt.legend(loc = (1.01, 0))
    plt.xlabel("date")
    plt.ylabel("counting")

# %%
X_hour_week = np.hstack([df.hour.values.reshape(-1,1), df.기온.values.reshape(-1,1),
                         df.temp.values.reshape(-1,1), df.light.values.reshape(-1,1),
                         df.voc.values.reshape(-1,1)])


reg1 = GradientBoostingRegressor(random_state=10, n_estimators=15, max_depth = 4, 
                                 learning_rate= 0.1, min_samples_leaf= 9, max_features= 1.0)

reg2 = RandomForestRegressor(random_state=10, n_estimators=10)

ereg = VotingRegressor(estimators=[('gb', reg1), ('rf', reg2)])

eval_on_features(X_hour_week, y , ereg)
# Out:
# 훈련 세트 R^2: 0.95
# 테스트 세트 R^2: 0.85
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 53664 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54868 missing from current font.
# ...

# %%
y_p
# Out:
# [array([0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.        , 0.0164232 , 0.08211599, 0.16090584, 0.2721991 ,
#         0.26836185, 0.31138546, 0.42923757, 0.59280619, 0.70023499,
#         0.72769686, 0.73593543, 0.67918088, 0.63707268, 0.68650405,
#         0.74600478, 0.69562096, 0.39265456, 0.22496002, 0.        ,
#         0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.0164232 , 0.08211599, 0.16090584, 0.25543572, 0.3452551 ,
#         0.3452551 , 0.35188151, 0.54754257, 0.88923711, 0.81417465,
#         0.91778779, 0.82526874, 0.75980775, 0.88068756, 0.86054885,
#         0.83460328, 0.42607336, 0.22778046, 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.        , 0.0164232 ,
#         0.08211599, 0.1711727 , 0.27331201, 0.30040071, 0.33448899,
#         0.34730453, 0.57431003, 0.94141467, 0.93042992, 0.90656555,
#         0.83217158, 0.80928669, 0.85688727, 0.85139489, 0.8309417 ,
# ...

# %%
yy1 = []

for i in y_p:
    yy1.append(i*120)
    
yy1
# Out:
# [array([  0.        ,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ,   1.97078372,   9.85391862,
#          19.30870033,  32.66389239,  32.20342232,  37.36625478,
#          51.50850867,  71.13674309,  84.02819857,  87.32362355,
#          88.31225104,  81.50170609,  76.44872113,  82.38048609,
#          89.52057353,  83.47451494,  47.11854732,  26.99520243,
#           0.        ,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ,   1.97078372,   9.85391862,
#          19.30870033,  30.65228621,  41.43061225,  41.43061225,
#          42.22578164,  65.70510863, 106.7084526 ,  97.70095768,
#         110.13453524,  99.03224858,  91.17692997, 105.68250717,
#         103.26586219, 100.15239415,  51.1288027 ,  27.3336553 ,
#           0.        ,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ,   1.97078372,   9.85391862,
#          20.54072357,  32.79744064,  36.04808479,  40.13867915,
# ...

# %%
predict= pd.DataFrame(np.transpose(yy1))
predict['predict_number'] = pd.DataFrame(np.transpose(yy1))

# %%
# predict = predict.drop(0, axis = 1)
# predict.loc[predict.predict_number<20, 'predict_congest'] = '1'
# predict.loc[(predict.predict_number>=20) & (predict.predict_number<40), 'predict_congest'] = '2'
# predict.loc[(predict.predict_number>=40) & (predict.predict_number<70), 'predict_congest'] = '3'
# predict.loc[(predict.predict_number>=70) & (predict.predict_number<100), 'predict_congest'] = '4'
# predict.loc[predict.predict_number>=100, 'predict_congest'] = '5'

# %%
predict.loc[predict.predict_number<15, 'predict_congest'] = '1'
predict.loc[(predict.predict_number>=15) & (predict.predict_number<40), 'predict_congest'] = '2'
predict.loc[(predict.predict_number>=40) & (predict.predict_number<60), 'predict_congest'] = '3'
predict.loc[(predict.predict_number>=60) & (predict.predict_number<100), 'predict_congest'] = '4'
predict.loc[predict.predict_number>=100, 'predict_congest'] = '5'

# %%
from sklearn.cluster import AgglomerativeClustering
import pandas as pd
import numpy as np

agg = AgglomerativeClustering(n_clusters=5)
assigment = agg.fit_predict(predict)
predict['cluster']= pd.DataFrame(np.transpose(assigment))

predict = predict.drop(0, axis=1)

plt.figure(figsize=(10,10))
plt.scatter(x=predict.cluster, y=predict.predict_number, alpha=0.5)
plt.title('cluster scatter plot')
plt.xlabel('cluster')
plt.ylabel('predict_number')
plt.show()

# %%
predict
# Out:
#      predict_number predict_congest  cluster
# 0          0.000000               1        2
# 1          0.000000               1        2
# 2          0.000000               1        2
# 3          0.000000               1        2
# 4          0.000000               1        2
# ..              ...             ...      ...
# 163       85.016826               4        0
# 164       85.016826               4        0
# 165       83.913905               4        0
# 166       46.459462               3        3
# 167       26.667234               2        4
#
# [168 rows x 3 columns]

# %%
y_t
# Out:
# [date
#  2019-10-07 00:00:00    0.000000
#  2019-10-07 01:00:00    0.000000
#  2019-10-07 02:00:00    0.000000
#  2019-10-07 03:00:00    0.000000
#  2019-10-07 04:00:00    0.000000
#                           ...
#  2019-10-13 19:00:00    0.576923
#  2019-10-13 20:00:00    0.641026
#  2019-10-13 21:00:00    0.576923
#  2019-10-13 22:00:00    0.282051
#  2019-10-13 23:00:00    0.153846
#  Name: real_number, Length: 168, dtype: float64]

# %%
yy2 = []

for i in y_t:
    yy2.append(i*120)
    
yy2
# Out:
# [date
#  2019-10-07 00:00:00     0.000000
#  2019-10-07 01:00:00     0.000000
#  2019-10-07 02:00:00     0.000000
#  2019-10-07 03:00:00     0.000000
#  2019-10-07 04:00:00     0.000000
#                           ...
#  2019-10-13 19:00:00    69.230769
#  2019-10-13 20:00:00    76.923077
#  2019-10-13 21:00:00    69.230769
#  2019-10-13 22:00:00    33.846154
#  2019-10-13 23:00:00    18.461538
#  Name: real_number, Length: 168, dtype: float64]

# %%
test = pd.DataFrame(np.transpose(yy2))
test['real_number'] = pd.DataFrame(np.transpose(yy2))

# %%
test.loc[test.real_number<15, 'real_congest'] = '1'
test.loc[(test.real_number>=15) & (test.real_number<40), 'real_congest'] = '2'
test.loc[(test.real_number>=40) & (test.real_number<60), 'real_congest'] = '3'
test.loc[(test.real_number>=60) & (test.real_number<100), 'real_congest'] = '4'
test.loc[test.real_number>=100, 'real_congest'] = '5'

# %%
test
# Out:
#              0  real_number real_congest
# 0     0.000000     0.000000            1
# 1     0.000000     0.000000            1
# 2     0.000000     0.000000            1
# 3     0.000000     0.000000            1
# 4     0.000000     0.000000            1
# ..         ...          ...          ...
# 163  69.230769    69.230769            4
# 164  76.923077    76.923077            4
# 165  69.230769    69.230769            4
# 166  33.846154    33.846154            2
# 167  18.461538    18.461538            2
#
# [168 rows x 3 columns]

# %%
test['real_number'].describe()
# Out:
# count    168.000000
# mean      42.783883
# std       37.962101
# min        0.000000
# 25%        1.153846
# 50%       39.230769
# 75%       76.923077
# max      120.000000
# Name: real_number, dtype: float64

# %%
test = pd.concat([test,predict], axis = 1)

# %%
test.loc[test.predict_congest==test.real_congest, 'result'] = True
test.loc[test.predict_congest!=test.real_congest, 'result'] = False

# %%
test
# Out:
#              0  real_number real_congest  predict_number predict_congest  \
# 0     0.000000     0.000000            1        0.000000               1
# 1     0.000000     0.000000            1        0.000000               1
# 2     0.000000     0.000000            1        0.000000               1
# 3     0.000000     0.000000            1        0.000000               1
# 4     0.000000     0.000000            1        0.000000               1
# ..         ...          ...          ...             ...             ...
# 163  69.230769    69.230769            4       85.016826               4
# 164  76.923077    76.923077            4       85.016826               4
# 165  69.230769    69.230769            4       83.913905               4
# 166  33.846154    33.846154            2       46.459462               3
# 167  18.461538    18.461538            2       26.667234               2
#
#      cluster  result
# 0          2    True
# 1          2    True
# 2          2    True
# ...

# %%
test1 = test[['predict_number','predict_congest']]

# %%
test1['hour'] = ap_data['date_hour'][408:576].values
# Out:
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test1['exam_congest'] = test1['predict_congest'].astype("int64")
# Out:
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test1.groupby(['hour'],as_index = False)['exam_congest'].mean()
# Out:
#     hour  exam_congest
# 0      0      1.000000
# 1      1      1.000000
# 2      2      1.000000
# 3      3      1.000000
# 4      4      1.000000
# 5      5      1.000000
# 6      6      1.000000
# 7      7      1.000000
# 8      8      2.000000
# 9      9      2.000000
# 10    10      2.857143
# 11    11      3.000000
# 12    12      3.000000
# 13    13      4.000000
# 14    14      4.857143
# 15    15      4.714286
# 16    16      4.857143
# 17    17      4.428571
# 18    18      4.000000
# 19    19      4.428571
# 20    20      4.571429
# 21    21      4.285714
# 22    22      3.000000
# 23    23      2.000000

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in _ensure_valid_index(self, value)
#    3519             try:
# -> 3520                 value = Series(value)
#    3521             except (ValueError, NotImplementedError, TypeError):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     312
# --> 313                 data = SingleBlockManager(data, index, fastpath=True)
#     314
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\internals\managers.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    1514         if not isinstance(block, Block):
# -> 1515             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    1516
#
# ...

# %%
ytrain = []

for i in y_tr:
    ytrain.append(i*120)
    
ytrain

# %%
ytr = pd.DataFrame(np.transpose(ytrain))
ytr['real_number'] = pd.DataFrame(np.transpose(ytrain))

# %%
ytr.loc[ytr.real_number<20, 'notexam_congest'] = '1'
ytr.loc[(ytr.real_number>=20) & (ytr.real_number<40), 'notexam_congest'] = '2'
ytr.loc[(ytr.real_number>=40) & (ytr.real_number<70), 'notexam_congest'] = '3'
ytr.loc[(ytr.real_number>=70) & (ytr.real_number<100), 'notexam_congest'] = '4'
ytr.loc[ytr.real_number>=100, 'notexam_congest'] = '5'

# %%
ytr['notexam_congest'] = ytr['notexam_congest'].astype("int64")

# %%
ytr['hour'] = ap_data['date_hour'][:408].values

# %%
ytr.groupby(['hour'], as_index = False)['notexam_congest'].mean()

# %%
congest['notexam_congest'] = ytr.groupby(['hour'], as_index = False)['notexam_congest'].mean()

# %%
ytr = pd.concat([ytr,test1],axis = 1)

# %%
ytr

# %%
ytr = ytr.drop(0)

# %%
ytr

# %%
ytr = ytr.drop([0,'real_number'], axis = 1)

# %%
ytr[e]

# %%
ytr = ytr.drop(['predict_number','predict_congest','hour'], axis = 1)

# %%
ytr

# %%
ap_data.groupby(['date_hour'], as_index=False)['real_number'].mean()

# %%
result = test['result'].sum()/len(test)

# %%
test['result'].sum()

# %%
print ("정확도 : " ,round(result * 100), "%")
