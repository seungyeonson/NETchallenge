# %%
import pandas as pd
import numpy as np

# %%
ap_data = pd.read_excel("exact_data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-36b13963a0b8> in <module>
# ----> 1 ap_data = pd.read_excel("exact_data.xlsx")
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     308
#     309     if not isinstance(io, ExcelFile):
# --> 310         io = ExcelFile(io, engine=engine)
#     311     elif engine and engine != io.engine:
#     312         raise ValueError(
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     817         self._io = _stringify_path(io)
#     818
# --> 819         self._reader = self._engines[engine](self._io)
#     820
#     821     def __fspath__(self):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     357             self.book = self.load_workbook(filepath_or_buffer)
#     358         elif isinstance(filepath_or_buffer, str):
# --> 359             self.book = self.load_workbook(filepath_or_buffer)
#     360         else:
#     361             raise ValueError(
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'exact_data.xlsx'

# %%
ap_data.head()

# %%
ap_data.info()

# %%
ap_data['calledstationid'].value_counts()
# Out:
# 34FCB96AF2F0    2033
# 34FCB96C1690    1775
# 34FCB96C1990    1346
# 34FCB96C1680    1309
# 34FCB96C1C10    1070
#                 ...
# 24DEC6A94A30       1
# 186472664D31       1
# 34FCB96A9520       1
# 34FCB96A8CC0       1
# 34FCB96C34E0       1
# Name: calledstationid, Length: 93, dtype: int64

# %%
#7열이라고 예상되는 것만 뽑음

ap_data = ap_data.loc[((ap_data['calledstationid'] == '34FCB96C1C10') | (ap_data['calledstationid'] == '34FCB96C1C00')), :]

# %%
ap_data = ap_data.reset_index(drop=True)

# %%
ap_data[:100]
# Out:
#     Unnamed: 0    username   place       acctstarttime        acctstoptime  \
# 0            9      151782  도서관열람실 2019-09-20 00:10:00 2019-09-20 00:11:00
# 1           35      121742  도서관열람실 2019-09-20 07:31:00 2019-09-20 09:51:00
# 2           40       b7931  도서관열람실 2019-09-20 07:35:00 2019-09-20 07:39:00
# 3           42      176272  도서관열람실 2019-09-20 07:39:00 2019-09-20 10:53:00
# 4           51  happy00727  도서관열람실 2019-09-20 07:59:00 2019-09-20 08:00:00
# ..         ...         ...     ...                 ...                 ...
# 95        1044      161437  도서관열람실 2019-09-20 13:03:00 2019-09-20 13:04:00
# 96        1049      163029  도서관열람실 2019-09-20 13:05:00 2019-09-20 13:13:00
# 97        1056      163029  도서관열람실 2019-09-20 13:05:00 2019-09-20 13:13:00
# 98        1060      145804  도서관열람실 2019-09-20 13:06:00 2019-09-20 14:32:00
# 99        1069      163029  도서관열람실 2019-09-20 13:08:00 2019-09-20 13:11:00
#
#     acctsessiontime calledstationid        ipaddress callingstationid  \
# 0                64    34FCB96C1C10  168.131.181.117     886B6E27E0B5
# 1              8405    34FCB96C1C10  168.131.181.117     3C9509853341
# 2               227    34FCB96C1C00  168.131.181.117     44783E0C17AA
# 3             11673    34FCB96C1C00  168.131.181.117     9CE6E7CDDA56
# 4                50    34FCB96C1C00  168.131.181.117     F8E61AFD6E5F
# ..              ...             ...              ...              ...
# 95               33    34FCB96C1C00  168.131.181.117     F0989DDAE0EF
# 96              471    34FCB96C1C10  168.131.181.117     F895EA33FEF3
# 97              471    34FCB96C1C10  168.131.181.117     F895EA33FEF3
# 98             5152    34FCB96C1C00  168.131.181.117     24F5AA72FB87
# 99              170    34FCB96C1C10  168.131.181.117     00C2C69F6E60
#
#     acctstarttime_year  acctstarttime_month  acctstarttime_day  \
# 0                 2019                    9                 20
# 1                 2019                    9                 20
# 2                 2019                    9                 20
# 3                 2019                    9                 20
# 4                 2019                    9                 20
# ..                 ...                  ...                ...
# 95                2019                    9                 20
# 96                2019                    9                 20
# 97                2019                    9                 20
# 98                2019                    9                 20
# 99                2019                    9                 20
#
#     acctstarttime_hour  acctstarttime_minute
# 0                    0                    10
# 1                    7                    31
# 2                    7                    35
# 3                    7                    39
# 4                    7                    59
# ..                 ...                   ...
# 95                  13                     3
# 96                  13                     5
# 97                  13                     5
# 98                  13                     6
# 99                  13                     8
#
# [100 rows x 14 columns]

# %%
ap_data[101:200]
# Out:
#      Unnamed: 0 username   place       acctstarttime        acctstoptime  \
# 101        1081   100490  도서관열람실 2019-09-20 13:09:00 2019-09-20 14:53:00
# 102        1085   160350  도서관열람실 2019-09-20 13:09:00 2019-09-20 13:43:00
# 103        1086   193482  도서관열람실 2019-09-20 13:09:00 2019-09-20 14:19:00
# 104        1087   160472  도서관열람실 2019-09-20 13:10:00 2019-09-20 13:10:00
# 105        1088   176604  도서관열람실 2019-09-20 13:10:00 2019-09-20 13:34:00
# ..          ...      ...     ...                 ...                 ...
# 195        1972   153067  도서관열람실 2019-09-20 15:40:00 2019-09-20 15:41:00
# 196        1978   151611  도서관열람실 2019-09-20 15:41:00 2019-09-20 15:43:00
# 197        1980   133369  도서관열람실 2019-09-20 15:41:00 2019-09-20 16:49:00
# 198        1993   152777  도서관열람실 2019-09-20 15:43:00 2019-09-20 15:44:00
# 199        2004   152777  도서관열람실 2019-09-20 15:44:00 2019-09-20 15:45:00
#
#      acctsessiontime calledstationid        ipaddress callingstationid  \
# 101             6219    34FCB96C1C10  168.131.181.117     647BCE6BEEA2
# 102             2013    34FCB96C1C10  168.131.181.117     9810E8ECD013
# 103             4166    34FCB96C1C00  168.131.181.117     BCA58BECA067
# 104               36    34FCB96C1C10  168.131.181.117     D4A33D9EEC26
# 105             1483    34FCB96C1C10  168.131.181.117     D013FD4D46EA
# ..               ...             ...              ...              ...
# 195               54    34FCB96C1C00  168.131.181.117     C0E8628AC26C
# 196               68    34FCB96C1C00  168.131.181.117     F895EA2A8836
# 197             4052    34FCB96C1C10  168.131.181.117     548CA0785145
# 198               46    34FCB96C1C10  168.131.181.117     F8E94EAC1295
# 199               36    34FCB96C1C10  168.131.181.117     F8E94EAC1295
#
#      acctstarttime_year  acctstarttime_month  acctstarttime_day  \
# 101                2019                    9                 20
# 102                2019                    9                 20
# 103                2019                    9                 20
# 104                2019                    9                 20
# 105                2019                    9                 20
# ..                  ...                  ...                ...
# 195                2019                    9                 20
# 196                2019                    9                 20
# 197                2019                    9                 20
# 198                2019                    9                 20
# 199                2019                    9                 20
#
#      acctstarttime_hour  acctstarttime_minute
# 101                  13                     9
# 102                  13                     9
# 103                  13                     9
# 104                  13                    10
# 105                  13                    10
# ..                  ...                   ...
# 195                  15                    40
# 196                  15                    41
# 197                  15                    41
# 198                  15                    43
# 199                  15                    44
#
# [99 rows x 14 columns]

# %%
ap_data[201:300]
# Out:
#      Unnamed: 0 username   place       acctstarttime        acctstoptime  \
# 201        2012   153067  도서관열람실 2019-09-20 15:45:00 2019-09-20 15:49:00
# 202        2022   152777  도서관열람실 2019-09-20 15:45:00 2019-09-20 15:46:00
# 203        2023   153067  도서관열람실 2019-09-20 15:45:00 2019-09-20 15:49:00
# 204        2031   152777  도서관열람실 2019-09-20 15:46:00 2019-09-20 15:47:00
# 205        2042   155215  도서관열람실 2019-09-20 15:49:00 2019-09-20 16:01:00
# ..          ...      ...     ...                 ...                 ...
# 295        3329   131660  도서관열람실 2019-09-20 19:20:00 2019-09-20 22:54:00
# 296        3337   140167  도서관열람실 2019-09-20 19:21:00 2019-09-20 19:22:00
# 297        3353   145773  도서관열람실 2019-09-20 19:24:00 2019-09-20 19:27:00
# 298        3379   130207  도서관열람실 2019-09-20 19:30:00 2019-09-20 19:48:00
# 299        3393   155215  도서관열람실 2019-09-20 19:35:00 2019-09-20 19:37:00
#
#      acctsessiontime calledstationid        ipaddress callingstationid  \
# 201              205    34FCB96C1C00  168.131.181.117     C0E8628AC26C
# 202               35    34FCB96C1C10  168.131.181.117     F8E94EAC1295
# 203              205    34FCB96C1C00  168.131.181.117     C0E8628AC26C
# 204               47    34FCB96C1C10  168.131.181.117     F8E94EAC1295
# 205              725    34FCB96C1C10  168.131.181.117     484BAA4B54C7
# ..               ...             ...              ...              ...
# 295            12870    34FCB96C1C00  168.131.181.117     40F02FF3CD68
# 296               68    34FCB96C1C10  168.131.181.117     948BC12F5F9C
# 297              182    34FCB96C1C10  168.131.181.117     34426253CC02
# 298             1110    34FCB96C1C00  168.131.181.117     B4F7A1E60C7B
# 299              137    34FCB96C1C10  168.131.181.117     5CC5D43A3874
#
#      acctstarttime_year  acctstarttime_month  acctstarttime_day  \
# 201                2019                    9                 20
# 202                2019                    9                 20
# 203                2019                    9                 20
# 204                2019                    9                 20
# 205                2019                    9                 20
# ..                  ...                  ...                ...
# 295                2019                    9                 20
# 296                2019                    9                 20
# 297                2019                    9                 20
# 298                2019                    9                 20
# 299                2019                    9                 20
#
#      acctstarttime_hour  acctstarttime_minute
# 201                  15                    45
# 202                  15                    45
# 203                  15                    45
# 204                  15                    46
# 205                  15                    49
# ..                  ...                   ...
# 295                  19                    20
# 296                  19                    21
# 297                  19                    24
# 298                  19                    30
# 299                  19                    35
#
# [99 rows x 14 columns]

# %%
date_data =pd.DataFrame()
date_data.loc[:,'date']=pd.Series(pd.date_range("2019-9-20 00:00", "2019-9-25 00:00", freq="H"))
date_data['all_num']=0

date_data['datetime'] = pd.to_datetime(date_data['date'])
date_data = date_data.set_index("datetime")
date_data.head(-1)
# Out:
#                                    date  all_num
# datetime
# 2019-09-20 00:00:00 2019-09-20 00:00:00        0
# 2019-09-20 01:00:00 2019-09-20 01:00:00        0
# 2019-09-20 02:00:00 2019-09-20 02:00:00        0
# 2019-09-20 03:00:00 2019-09-20 03:00:00        0
# 2019-09-20 04:00:00 2019-09-20 04:00:00        0
# ...                                 ...      ...
# 2019-09-24 19:00:00 2019-09-24 19:00:00        0
# 2019-09-24 20:00:00 2019-09-24 20:00:00        0
# 2019-09-24 21:00:00 2019-09-24 21:00:00        0
# 2019-09-24 22:00:00 2019-09-24 22:00:00        0
# 2019-09-24 23:00:00 2019-09-24 23:00:00        0
#
# [120 rows x 2 columns]

# %%
date_data.head(5)
# Out:
#                                    date  all_num
# datetime
# 2019-09-20 00:00:00 2019-09-20 00:00:00        0
# 2019-09-20 01:00:00 2019-09-20 01:00:00        0
# 2019-09-20 02:00:00 2019-09-20 02:00:00        0
# 2019-09-20 03:00:00 2019-09-20 03:00:00        0
# 2019-09-20 04:00:00 2019-09-20 04:00:00        0

# %%
import datetime
timeStr = '2019-09-21 12:11:32'
Thistime = datetime.datetime.strptime(timeStr, '%Y-%m-%d %H:%M:%S')
yourDatetime = Thistime.replace(hour=Thistime.hour+1, minute=0, second=0)
print(yourDatetime)
ex = pd.to_datetime(yourDatetime, infer_datetime_format=True)
print(ex)
# Out:
# 2019-09-21 13:00:00
# 2019-09-21 13:00:00

# %%
import sys
for idx1, row1 in ap_data.iterrows():
    #print(row1.acctsessiontime)
    for i in range(int(row1.acctsessiontime)//3600 + 1):
        date_data.loc[(date_data.index.hour==row1.acctstarttime_hour+i) & (date_data.index.day==row1.acctstarttime_day),'all_num']+=1
        #print(i)
        #print(row1.acctstarttime_hour, row1.acctstarttime_year)
        #date_data.ix[(row1.'acctstarttime_hour'  date_data.ix[시간단위 자르기(row1.)+i(1시간 추가)]['allnum']+=1

# %%
date_data.head(50)
# Out:
#                                    date  all_num
# datetime
# 2019-09-20 00:00:00 2019-09-20 00:00:00        1
# 2019-09-20 01:00:00 2019-09-20 01:00:00        0
# 2019-09-20 02:00:00 2019-09-20 02:00:00        0
# 2019-09-20 03:00:00 2019-09-20 03:00:00        0
# 2019-09-20 04:00:00 2019-09-20 04:00:00        0
# 2019-09-20 05:00:00 2019-09-20 05:00:00        0
# 2019-09-20 06:00:00 2019-09-20 06:00:00        0
# 2019-09-20 07:00:00 2019-09-20 07:00:00        4
# 2019-09-20 08:00:00 2019-09-20 08:00:00       11
# 2019-09-20 09:00:00 2019-09-20 09:00:00       20
# 2019-09-20 10:00:00 2019-09-20 10:00:00       27
# 2019-09-20 11:00:00 2019-09-20 11:00:00       31
# 2019-09-20 12:00:00 2019-09-20 12:00:00       32
# 2019-09-20 13:00:00 2019-09-20 13:00:00       40
# 2019-09-20 14:00:00 2019-09-20 14:00:00       42
# 2019-09-20 15:00:00 2019-09-20 15:00:00       65
# 2019-09-20 16:00:00 2019-09-20 16:00:00       38
# 2019-09-20 17:00:00 2019-09-20 17:00:00       33
# 2019-09-20 18:00:00 2019-09-20 18:00:00       28
# 2019-09-20 19:00:00 2019-09-20 19:00:00       21
# 2019-09-20 20:00:00 2019-09-20 20:00:00       12
# 2019-09-20 21:00:00 2019-09-20 21:00:00       19
# 2019-09-20 22:00:00 2019-09-20 22:00:00       16
# 2019-09-20 23:00:00 2019-09-20 23:00:00        6
# 2019-09-21 00:00:00 2019-09-21 00:00:00        1
# 2019-09-21 01:00:00 2019-09-21 01:00:00        0
# 2019-09-21 02:00:00 2019-09-21 02:00:00        0
# 2019-09-21 03:00:00 2019-09-21 03:00:00        0
# 2019-09-21 04:00:00 2019-09-21 04:00:00        0
# 2019-09-21 05:00:00 2019-09-21 05:00:00        0
# 2019-09-21 06:00:00 2019-09-21 06:00:00        0
# 2019-09-21 07:00:00 2019-09-21 07:00:00        3
# 2019-09-21 08:00:00 2019-09-21 08:00:00        6
# 2019-09-21 09:00:00 2019-09-21 09:00:00       10
# 2019-09-21 10:00:00 2019-09-21 10:00:00       10
# 2019-09-21 11:00:00 2019-09-21 11:00:00       12
# 2019-09-21 12:00:00 2019-09-21 12:00:00       14
# 2019-09-21 13:00:00 2019-09-21 13:00:00       13
# 2019-09-21 14:00:00 2019-09-21 14:00:00       25
# 2019-09-21 15:00:00 2019-09-21 15:00:00       26
# 2019-09-21 16:00:00 2019-09-21 16:00:00       32
# 2019-09-21 17:00:00 2019-09-21 17:00:00       19
# 2019-09-21 18:00:00 2019-09-21 18:00:00       17
# 2019-09-21 19:00:00 2019-09-21 19:00:00       11
# 2019-09-21 20:00:00 2019-09-21 20:00:00       15
# 2019-09-21 21:00:00 2019-09-21 21:00:00       13
# 2019-09-21 22:00:00 2019-09-21 22:00:00        7
# 2019-09-21 23:00:00 2019-09-21 23:00:00        6
# 2019-09-22 00:00:00 2019-09-22 00:00:00        1
# 2019-09-22 01:00:00 2019-09-22 01:00:00        0

# %%
ap_data.head()
# Out:
#    Unnamed: 0    username   place       acctstarttime        acctstoptime  \
# 0           9      151782  도서관열람실 2019-09-20 00:10:00 2019-09-20 00:11:00
# 1          35      121742  도서관열람실 2019-09-20 07:31:00 2019-09-20 09:51:00
# 2          40       b7931  도서관열람실 2019-09-20 07:35:00 2019-09-20 07:39:00
# 3          42      176272  도서관열람실 2019-09-20 07:39:00 2019-09-20 10:53:00
# 4          51  happy00727  도서관열람실 2019-09-20 07:59:00 2019-09-20 08:00:00
#
#    acctsessiontime calledstationid        ipaddress callingstationid  \
# 0               64    34FCB96C1C10  168.131.181.117     886B6E27E0B5
# 1             8405    34FCB96C1C10  168.131.181.117     3C9509853341
# 2              227    34FCB96C1C00  168.131.181.117     44783E0C17AA
# 3            11673    34FCB96C1C00  168.131.181.117     9CE6E7CDDA56
# 4               50    34FCB96C1C00  168.131.181.117     F8E61AFD6E5F
#
#    acctstarttime_year  acctstarttime_month  acctstarttime_day  \
# 0                2019                    9                 20
# 1                2019                    9                 20
# 2                2019                    9                 20
# 3                2019                    9                 20
# 4                2019                    9                 20
#
#    acctstarttime_hour  acctstarttime_minute
# 0                   0                    10
# 1                   7                    31
# 2                   7                    35
# 3                   7                    39
# 4                   7                    59
