# %%
import pandas as pd
import numpy as np

# %%
ap_data = pd.read_excel("exact_data_7.xlsx")

# %%
ap_data.head(-1)
# Out:
#       Unnamed: 0 username   place       acctstarttime        acctstoptime  \
# 0              0      NaN  도서관열람실 2019-09-20 00:10:00 2019-09-20 00:11:00
# 1              1      NaN  도서관열람실 2019-09-20 00:10:00 2019-09-20 00:11:00
# 2              2   151782  도서관열람실 2019-09-20 00:10:00 2019-09-20 00:11:00
# 3              3      NaN  도서관열람실 2019-09-20 07:31:00 2019-09-20 09:51:00
# 4              4   121742  도서관열람실 2019-09-20 07:31:00 2019-09-20 09:51:00
# ...          ...      ...     ...                 ...                 ...
# 2681        2681   141188  도서관열람실 2019-09-30 22:00:00 2019-09-30 22:12:00
# 2682        2682   148460  도서관열람실 2019-09-30 22:30:00 2019-09-30 23:33:00
# 2683        2683   174403  도서관열람실 2019-09-30 22:37:00 2019-09-30 23:02:00
# 2684        2684   130328  도서관열람실 2019-09-30 22:51:00 2019-09-30 22:52:00
# 2685        2685   104867  도서관열람실 2019-09-30 22:54:00 2019-09-30 23:34:00
#
#       acctsessiontime calledstationid        ipaddress callingstationid  \
# 0                64.0    34FCB96C1C10  168.131.181.117     886B6E27E0B5
# 1                64.0    34FCB96C1C10  168.131.181.117     886B6E27E0B5
# 2                64.0    34FCB96C1C10  168.131.181.117     886B6E27E0B5
# 3              8405.0    34FCB96C1C10  168.131.181.117     3C9509853341
# 4              8405.0    34FCB96C1C10  168.131.181.117     3C9509853341
# ...               ...             ...              ...              ...
# 2681            694.0    34FCB96C1C10  168.131.181.117     B4B6767157B9
# 2682           3736.0    34FCB96C1C10  168.131.181.117     D4A33D3A4EEE
# 2683           1473.0    34FCB96C1C10  168.131.181.117     D0C5F3D6671C
# 2684             81.0    34FCB96C1C10  168.131.181.117     D88F7626F4D1
# 2685           2379.0    34FCB96C1C10  168.131.181.117     C8FF2836A60F
#
#       acctstarttime_year  acctstarttime_month  acctstarttime_day  \
# 0                   2019                    9                 20
# 1                   2019                    9                 20
# 2                   2019                    9                 20
# 3                   2019                    9                 20
# 4                   2019                    9                 20
# ...                  ...                  ...                ...
# 2681                2019                    9                 30
# 2682                2019                    9                 30
# 2683                2019                    9                 30
# 2684                2019                    9                 30
# 2685                2019                    9                 30
#
#       acctstarttime_hour  acctstarttime_minute
# 0                      0                    10
# 1                      0                    10
# 2                      0                    10
# 3                      7                    31
# 4                      7                    31
# ...                  ...                   ...
# 2681                  22                     0
# 2682                  22                    30
# 2683                  22                    37
# 2684                  22                    51
# 2685                  22                    54
#
# [2686 rows x 14 columns]

# %%
ap_data = ap_data.loc[ap_data['username'].notnull(),:]

# %%
ap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1966 entries, 2 to 2686
# Data columns (total 14 columns):
# Unnamed: 0              1966 non-null int64
# username                1966 non-null object
# place                   1966 non-null object
# acctstarttime           1966 non-null datetime64[ns]
# acctstoptime            1966 non-null datetime64[ns]
# acctsessiontime         1966 non-null float64
# calledstationid         1966 non-null object
# ipaddress               1966 non-null object
# callingstationid        1966 non-null object
# acctstarttime_year      1966 non-null int64
# acctstarttime_month     1966 non-null int64
# acctstarttime_day       1966 non-null int64
# acctstarttime_hour      1966 non-null int64
# acctstarttime_minute    1966 non-null int64
# dtypes: datetime64[ns](2), float64(1), int64(6), object(5)
# memory usage: 230.4+ KB

# %%
ap_data.head()
# Out:
#     Unnamed: 0    username   place       acctstarttime        acctstoptime  \
# 2            2      151782  도서관열람실 2019-09-20 00:10:00 2019-09-20 00:11:00
# 4            4      121742  도서관열람실 2019-09-20 07:31:00 2019-09-20 09:51:00
# 6            6       b7931  도서관열람실 2019-09-20 07:35:00 2019-09-20 07:39:00
# 8            8      176272  도서관열람실 2019-09-20 07:39:00 2019-09-20 10:53:00
# 10          10  happy00727  도서관열람실 2019-09-20 07:59:00 2019-09-20 08:00:00
#
#     acctsessiontime calledstationid        ipaddress callingstationid  \
# 2              64.0    34FCB96C1C10  168.131.181.117     886B6E27E0B5
# 4            8405.0    34FCB96C1C10  168.131.181.117     3C9509853341
# 6             227.0    34FCB96C1C00  168.131.181.117     44783E0C17AA
# 8           11673.0    34FCB96C1C00  168.131.181.117     9CE6E7CDDA56
# 10             50.0    34FCB96C1C00  168.131.181.117     F8E61AFD6E5F
#
#     acctstarttime_year  acctstarttime_month  acctstarttime_day  \
# 2                 2019                    9                 20
# 4                 2019                    9                 20
# 6                 2019                    9                 20
# 8                 2019                    9                 20
# 10                2019                    9                 20
#
#     acctstarttime_hour  acctstarttime_minute
# 2                    0                    10
# 4                    7                    31
# 6                    7                    35
# 8                    7                    39
# 10                   7                    59

# %%
ap_data = ap_data.reset_index(drop=True)

# %%
ap_data = ap_data.drop('Unnamed: 0', axis = 1)

# %%
ap_data.head()
# Out:
#      username   place       acctstarttime        acctstoptime  \
# 0      151782  도서관열람실 2019-09-20 00:10:00 2019-09-20 00:11:00
# 1      121742  도서관열람실 2019-09-20 07:31:00 2019-09-20 09:51:00
# 2       b7931  도서관열람실 2019-09-20 07:35:00 2019-09-20 07:39:00
# 3      176272  도서관열람실 2019-09-20 07:39:00 2019-09-20 10:53:00
# 4  happy00727  도서관열람실 2019-09-20 07:59:00 2019-09-20 08:00:00
#
#    acctsessiontime calledstationid        ipaddress callingstationid  \
# 0             64.0    34FCB96C1C10  168.131.181.117     886B6E27E0B5
# 1           8405.0    34FCB96C1C10  168.131.181.117     3C9509853341
# 2            227.0    34FCB96C1C00  168.131.181.117     44783E0C17AA
# 3          11673.0    34FCB96C1C00  168.131.181.117     9CE6E7CDDA56
# 4             50.0    34FCB96C1C00  168.131.181.117     F8E61AFD6E5F
#
#    acctstarttime_year  acctstarttime_month  acctstarttime_day  \
# 0                2019                    9                 20
# 1                2019                    9                 20
# 2                2019                    9                 20
# 3                2019                    9                 20
# 4                2019                    9                 20
#
#    acctstarttime_hour  acctstarttime_minute
# 0                   0                    10
# 1                   7                    31
# 2                   7                    35
# 3                   7                    39
# 4                   7                    59

# %%
#7열이라고 예상되는 것만 뽑음

# ap_data = ap_data.loc[((ap_data['calledstationid'] == '34FCB96C1C10') | (ap_data['calledstationid'] == '34FCB96C1C00')), :]

# %%
ap_data = ap_data.loc[((ap_data['ipaddress'] == '168.131.181.117')), :]

# %%
ap_data = ap_data.reset_index(drop=True)

# %%
ap_data.head(-1)
# Out:
#         username   place       acctstarttime        acctstoptime  \
# 0         151782  도서관열람실 2019-09-20 00:10:00 2019-09-20 00:11:00
# 1         121742  도서관열람실 2019-09-20 07:31:00 2019-09-20 09:51:00
# 2          b7931  도서관열람실 2019-09-20 07:35:00 2019-09-20 07:39:00
# 3         176272  도서관열람실 2019-09-20 07:39:00 2019-09-20 10:53:00
# 4     happy00727  도서관열람실 2019-09-20 07:59:00 2019-09-20 08:00:00
# ...          ...     ...                 ...                 ...
# 1960      141188  도서관열람실 2019-09-30 22:00:00 2019-09-30 22:12:00
# 1961      148460  도서관열람실 2019-09-30 22:30:00 2019-09-30 23:33:00
# 1962      174403  도서관열람실 2019-09-30 22:37:00 2019-09-30 23:02:00
# 1963      130328  도서관열람실 2019-09-30 22:51:00 2019-09-30 22:52:00
# 1964      104867  도서관열람실 2019-09-30 22:54:00 2019-09-30 23:34:00
#
#       acctsessiontime calledstationid        ipaddress callingstationid  \
# 0                64.0    34FCB96C1C10  168.131.181.117     886B6E27E0B5
# 1              8405.0    34FCB96C1C10  168.131.181.117     3C9509853341
# 2               227.0    34FCB96C1C00  168.131.181.117     44783E0C17AA
# 3             11673.0    34FCB96C1C00  168.131.181.117     9CE6E7CDDA56
# 4                50.0    34FCB96C1C00  168.131.181.117     F8E61AFD6E5F
# ...               ...             ...              ...              ...
# 1960            694.0    34FCB96C1C10  168.131.181.117     B4B6767157B9
# 1961           3736.0    34FCB96C1C10  168.131.181.117     D4A33D3A4EEE
# 1962           1473.0    34FCB96C1C10  168.131.181.117     D0C5F3D6671C
# 1963             81.0    34FCB96C1C10  168.131.181.117     D88F7626F4D1
# 1964           2379.0    34FCB96C1C10  168.131.181.117     C8FF2836A60F
#
#       acctstarttime_year  acctstarttime_month  acctstarttime_day  \
# 0                   2019                    9                 20
# 1                   2019                    9                 20
# 2                   2019                    9                 20
# 3                   2019                    9                 20
# 4                   2019                    9                 20
# ...                  ...                  ...                ...
# 1960                2019                    9                 30
# 1961                2019                    9                 30
# 1962                2019                    9                 30
# 1963                2019                    9                 30
# 1964                2019                    9                 30
#
#       acctstarttime_hour  acctstarttime_minute
# 0                      0                    10
# 1                      7                    31
# 2                      7                    35
# 3                      7                    39
# 4                      7                    59
# ...                  ...                   ...
# 1960                  22                     0
# 1961                  22                    30
# 1962                  22                    37
# 1963                  22                    51
# 1964                  22                    54
#
# [1965 rows x 13 columns]

# %%
date_data =pd.DataFrame()
date_data.loc[:,'date']=pd.Series(pd.date_range("2019-9-20 00:00", "2019-10-01 00:00", freq="H"))
date_data['all_num']=0

date_data['datetime'] = pd.to_datetime(date_data['date'])
date_data = date_data.set_index("datetime")
date_data.head(-1)
# Out:
#                                    date  all_num
# datetime
# 2019-09-20 00:00:00 2019-09-20 00:00:00        0
# 2019-09-20 01:00:00 2019-09-20 01:00:00        0
# 2019-09-20 02:00:00 2019-09-20 02:00:00        0
# 2019-09-20 03:00:00 2019-09-20 03:00:00        0
# 2019-09-20 04:00:00 2019-09-20 04:00:00        0
# ...                                 ...      ...
# 2019-09-30 19:00:00 2019-09-30 19:00:00        0
# 2019-09-30 20:00:00 2019-09-30 20:00:00        0
# 2019-09-30 21:00:00 2019-09-30 21:00:00        0
# 2019-09-30 22:00:00 2019-09-30 22:00:00        0
# 2019-09-30 23:00:00 2019-09-30 23:00:00        0
#
# [264 rows x 2 columns]

# %%
date_data.head(5)
# Out:
#                                    date  all_num
# datetime
# 2019-09-20 00:00:00 2019-09-20 00:00:00        0
# 2019-09-20 01:00:00 2019-09-20 01:00:00        0
# 2019-09-20 02:00:00 2019-09-20 02:00:00        0
# 2019-09-20 03:00:00 2019-09-20 03:00:00        0
# 2019-09-20 04:00:00 2019-09-20 04:00:00        0

# %%
import datetime
timeStr = '2019-09-21 12:11:32'
Thistime = datetime.datetime.strptime(timeStr, '%Y-%m-%d %H:%M:%S')
yourDatetime = Thistime.replace(hour=Thistime.hour+1, minute=0, second=0)
print(yourDatetime)
ex = pd.to_datetime(yourDatetime, infer_datetime_format=True)
print(ex)
# Out:
# 2019-09-21 13:00:00
# 2019-09-21 13:00:00

# %%
import sys
for idx1, row1 in ap_data.iterrows():
    #print(row1.acctsessiontime)
    for i in range(int(row1.acctsessiontime)//3600 + 1):
        date_data.loc[(date_data.index.hour==row1.acctstarttime_hour+i) & (date_data.index.day==row1.acctstarttime_day),'all_num']+=1
        #print(i)
        #print(row1.acctstarttime_hour, row1.acctstarttime_year)
        #date_data.ix[(row1.'acctstarttime_hour'  date_data.ix[시간단위 자르기(row1.)+i(1시간 추가)]['allnum']+=1

# %%
date_data.head(50)
# Out:
#                                    date  all_num
# datetime
# 2019-09-20 00:00:00 2019-09-20 00:00:00        1
# 2019-09-20 01:00:00 2019-09-20 01:00:00        0
# 2019-09-20 02:00:00 2019-09-20 02:00:00        0
# 2019-09-20 03:00:00 2019-09-20 03:00:00        0
# 2019-09-20 04:00:00 2019-09-20 04:00:00        0
# 2019-09-20 05:00:00 2019-09-20 05:00:00        0
# 2019-09-20 06:00:00 2019-09-20 06:00:00        0
# 2019-09-20 07:00:00 2019-09-20 07:00:00        4
# 2019-09-20 08:00:00 2019-09-20 08:00:00       10
# 2019-09-20 09:00:00 2019-09-20 09:00:00       18
# 2019-09-20 10:00:00 2019-09-20 10:00:00       25
# 2019-09-20 11:00:00 2019-09-20 11:00:00       28
# 2019-09-20 12:00:00 2019-09-20 12:00:00       22
# 2019-09-20 13:00:00 2019-09-20 13:00:00       29
# 2019-09-20 14:00:00 2019-09-20 14:00:00       30
# 2019-09-20 15:00:00 2019-09-20 15:00:00       41
# 2019-09-20 16:00:00 2019-09-20 16:00:00       32
# 2019-09-20 17:00:00 2019-09-20 17:00:00       29
# 2019-09-20 18:00:00 2019-09-20 18:00:00       22
# 2019-09-20 19:00:00 2019-09-20 19:00:00       17
# 2019-09-20 20:00:00 2019-09-20 20:00:00       12
# 2019-09-20 21:00:00 2019-09-20 21:00:00       16
# 2019-09-20 22:00:00 2019-09-20 22:00:00       14
# 2019-09-20 23:00:00 2019-09-20 23:00:00        6
# 2019-09-21 00:00:00 2019-09-21 00:00:00        1
# 2019-09-21 01:00:00 2019-09-21 01:00:00        0
# 2019-09-21 02:00:00 2019-09-21 02:00:00        0
# 2019-09-21 03:00:00 2019-09-21 03:00:00        0
# 2019-09-21 04:00:00 2019-09-21 04:00:00        0
# 2019-09-21 05:00:00 2019-09-21 05:00:00        0
# 2019-09-21 06:00:00 2019-09-21 06:00:00        0
# 2019-09-21 07:00:00 2019-09-21 07:00:00        4
# 2019-09-21 08:00:00 2019-09-21 08:00:00        6
# 2019-09-21 09:00:00 2019-09-21 09:00:00        8
# 2019-09-21 10:00:00 2019-09-21 10:00:00        9
# 2019-09-21 11:00:00 2019-09-21 11:00:00       11
# 2019-09-21 12:00:00 2019-09-21 12:00:00       12
# 2019-09-21 13:00:00 2019-09-21 13:00:00       14
# 2019-09-21 14:00:00 2019-09-21 14:00:00       23
# 2019-09-21 15:00:00 2019-09-21 15:00:00       24
# 2019-09-21 16:00:00 2019-09-21 16:00:00       29
# 2019-09-21 17:00:00 2019-09-21 17:00:00       18
# 2019-09-21 18:00:00 2019-09-21 18:00:00       14
# 2019-09-21 19:00:00 2019-09-21 19:00:00       11
# 2019-09-21 20:00:00 2019-09-21 20:00:00       14
# 2019-09-21 21:00:00 2019-09-21 21:00:00       10
# 2019-09-21 22:00:00 2019-09-21 22:00:00        8
# 2019-09-21 23:00:00 2019-09-21 23:00:00        7
# 2019-09-22 00:00:00 2019-09-22 00:00:00        1
# 2019-09-22 01:00:00 2019-09-22 01:00:00        0

# %%
date_data.to_excel('exact_data_910_log_7.xlsx')
