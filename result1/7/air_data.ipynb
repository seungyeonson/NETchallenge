# %%
import numpy as np
import pandas as pd

# %%
air = pd.read_csv('7-3.csv')

# %%
air
# Out:
#      timestamp(Asia/Seoul)  score  temp(°C)  humid     co2    voc  pm25  \
# 0          2019-09-20 0:00   74.0      25.7   41.0  4459.0  533.8     0
# 1          2019-09-20 0:15   74.0      25.8   41.2  4348.0  530.0     0
# 2          2019-09-20 0:30   74.3      25.9   41.8  4168.0  522.5     0
# 3          2019-09-20 0:45   75.0      25.9   42.3  3991.1  514.6     0
# 4          2019-09-20 1:00   75.0      25.9   42.5  3946.6  512.3     0
# ...                    ...    ...       ...    ...     ...    ...   ...
# 1051      2019-09-30 22:45   66.3      27.1   43.6  5000.0  742.0     0
# 1052      2019-09-30 23:00   66.9      27.0   42.9  5000.0  711.4     0
# 1053      2019-09-30 23:15   67.0      26.7   42.6  5000.0  698.3     0
# 1054      2019-09-30 23:30   67.6      26.5   42.7  5000.0  694.2     0
# 1055      2019-09-30 23:45   67.6      26.5   44.5  5000.0  746.8     0
#
#       light  noise
# 0     349.0   50.0
# 1     158.9   49.9
# 2       0.0   49.9
# 3       0.0   50.0
# 4       0.0   50.0
# ...     ...    ...
# 1051  343.9   52.7
# 1052  341.0   52.4
# 1053  345.7   52.3
# 1054  345.8   52.5
# 1055  344.6   51.3
#
# [1056 rows x 9 columns]

# %%
air1 = pd.read_csv('7-4.csv')

# %%
air1[:1056]
# Out:
#      timestamp(Asia/Seoul)  score  temp(°C)  humid     co2     voc  pm25  \
# 0          2019-09-20 0:00   74.1      25.5   41.7  4262.3   613.6   5.6
# 1          2019-09-20 0:15   74.0      25.6   42.0  4190.8   612.9   5.7
# 2          2019-09-20 0:30   74.2      25.7   42.5  4045.0   586.6   6.0
# 3          2019-09-20 0:45   74.6      25.7   43.0  3881.4   575.3   6.1
# 4          2019-09-20 1:00   74.8      25.7   43.3  3797.8   570.8   6.1
# ...                    ...    ...       ...    ...     ...     ...   ...
# 1051      2019-09-30 22:45   67.8      25.2   49.5  5000.0  1164.8  13.3
# 1052      2019-09-30 23:00   68.8      25.1   48.8  5000.0  1134.9  13.2
# 1053      2019-09-30 23:15   69.7      25.1   48.2  5000.0  1122.8  12.8
# 1054      2019-09-30 23:30   69.1      25.4   46.9  5000.0  1098.3  12.9
# 1055      2019-09-30 23:45   65.2      26.2   45.0  5000.0  1052.4  13.3
#
#       light  noise
# 0     395.1   50.4
# 1     179.9   50.2
# 2       0.0   50.2
# 3       0.0   50.2
# 4       0.0   50.2
# ...     ...    ...
# 1051  393.0   52.8
# 1052  391.8   52.5
# 1053  393.4   52.2
# 1054  393.4   52.2
# 1055  393.5   51.3
#
# [1056 rows x 9 columns]

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2799 entries, 0 to 2798
# Data columns (total 9 columns):
# timestamp(Asia/Seoul)    2799 non-null object
# score                    2799 non-null float64
# temp(°C)                 2799 non-null float64
# humid                    2799 non-null float64
# co2                      2799 non-null float64
# voc                      2799 non-null float64
# pm25                     2799 non-null int64
# light                    2799 non-null float64
# noise                    2799 non-null float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 196.9+ KB

# %%
air1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 9 columns):
# timestamp(Asia/Seoul)    2800 non-null object
# score                    2800 non-null float64
# temp(°C)                 2800 non-null float64
# humid                    2800 non-null float64
# co2                      2800 non-null float64
# voc                      2800 non-null float64
# pm25                     2800 non-null float64
# light                    2800 non-null float64
# noise                    2800 non-null float64
# dtypes: float64(8), object(1)
# memory usage: 197.0+ KB

# %%
air_data = pd.DataFrame()

air_data['timestamp(Asia/Seoul)'] = air['timestamp(Asia/Seoul)']
air_data['temp(°C)'] = (air['temp(°C)'] + air1['temp(°C)'])/2
air_data['humid'] = (air['humid'] + air1['humid'])/2
air_data['co2'] = (air['co2'] + air1['co2'])/2
air_data['voc'] = (air['voc'] + air1['voc'])/2
air_data['pm25'] = (air['pm25'] + air1['pm25'])/2
air_data['light'] = (air['light'] + air1['light'])/2
air_data['noise'] = (air['noise'] + air1['noise'])/2

# %%
air_data.head(-1)
# Out:
#      timestamp(Asia/Seoul)  temp(°C)  humid      co2     voc  pm25   light  \
# 0          2019-09-20 0:00     25.60  41.35  4360.65  573.70  2.80  372.05
# 1          2019-09-20 0:15     25.70  41.60  4269.40  571.45  2.85  169.40
# 2          2019-09-20 0:30     25.80  42.15  4106.50  554.55  3.00    0.00
# 3          2019-09-20 0:45     25.80  42.65  3936.25  544.95  3.05    0.00
# 4          2019-09-20 1:00     25.80  42.90  3872.20  541.55  3.05    0.00
# ...                    ...       ...    ...      ...     ...   ...     ...
# 2793      2019-10-19 17:00     27.35  51.40  1794.75  361.65  4.55  378.50
# 2794      2019-10-19 17:15     27.30  51.85  1818.40  368.45  4.40  371.05
# 2795      2019-10-19 17:30     27.20  51.95  1765.60  364.70  4.95  368.55
# 2796      2019-10-19 17:45     27.10  52.30  1686.30  356.70  5.30  365.35
# 2797      2019-10-19 18:00     27.00  52.55  1544.90  337.20  5.45  364.35
#
#       noise
# 0     50.20
# 1     50.05
# 2     50.05
# 3     50.10
# 4     50.10
# ...     ...
# 2793  52.15
# 2794  52.00
# 2795  52.25
# 2796  52.30
# 2797  52.55
#
# [2798 rows x 8 columns]

# %%
air_data['timestamp(Asia/Seoul)'] = pd.to_datetime(air_data['timestamp(Asia/Seoul)']) 

air_data.set_index(air_data['timestamp(Asia/Seoul)'], inplace=True)

air_data = air_data.resample('60T', how={'temp(°C)':np.average,'humid':np.average, 
                            'co2':np.average, 'voc':np.average, 'pm25':np.average, 'light':np.average, 'noise':np.average}).fillna(0)
# Out:
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\numpy\lib\function_base.py:390: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
air_data.head()
# Out:
#                        temp(°C)    humid        co2       voc    pm25  \
# timestamp(Asia/Seoul)
# 2019-09-20 00:00:00     25.7250  41.9375  4168.2000  561.1625  2.9250
# 2019-09-20 01:00:00     25.8750  43.3125  3699.7375  531.6500  3.2750
# 2019-09-20 02:00:00     26.0375  43.9500  3313.8625  508.0750  3.6500
# 2019-09-20 03:00:00     25.6625  46.5750  2379.5625  403.8250  4.6625
# 2019-09-20 04:00:00     25.4250  48.7875  1008.6500  209.7375  6.8500
#
#                           light    noise
# timestamp(Asia/Seoul)
# 2019-09-20 00:00:00    135.3625  50.1000
# 2019-09-20 01:00:00      0.0000  50.0875
# 2019-09-20 02:00:00      0.0000  50.0750
# 2019-09-20 03:00:00    171.5125  51.7000
# 2019-09-20 04:00:00      0.0000  50.2250

# %%
air_data.to_excel('air910.xlsx')
